# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('../Data/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X=data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']].values
print('shape of X is ',X.shape)


y=data['Outcome'].values.reshape(-1,1)
print('shape of y',y.shape)
# Out:
# shape of X is  (768, 8)
# shape of y (768, 1)

# %%
X_train =X[0:761]
X_test=X[761:]

print(X_train.shape)
y_train=y[0:761].reshape(-1,1)
y_true=y[761:]
y=y.reshape(-1,1)
print(y_train.shape)
print(X_test.shape)
# Out:
# (761, 8)
# (761, 1)
# (7, 8)

# %% [markdown]
# mu1 = -1
# mu2 = 3
# sig1 = 0.5
# sig2 = 1
# N = 100
# np.random.seed(10)
# x11=np.random.randn(N,1)*sig1 + mu1
# x12=np.random.randn(N,1)*sig1 + mu1+3
# x21=np.random.randn(N,1)*sig2 + mu2
# x22=np.random.randn(N,1)*sig2 + mu2+3
# c = np.vstack((np.zeros((N,1)), np.ones((N,1))))
# x1 = np.hstack((x11,x12))
# x2 = np.hstack((x21,x22))
#
# X = np.hstack( (np.vstack( (x1,x2) ),c) )
# np.random.shuffle(X)
# datasetttt = pd.DataFrame(data=X, columns=['x','y','c'])

# %% [markdown]
# datasetttt.head()

# %% [markdown]
# X=datasetttt[['x','y']].values
# y=datasetttt['c'].values
#
# X_train=X[:190]
#
# X_test=X[190:]
# y_true=y[190:]
# y_train=y[:190].reshape(-1,1)
#
# print(X_train.shape)
# print(y_train.shape)
# print(X_test.shape)

# %%
class LogisticRegresion:
    def __init__(self, lr=0.01, max_iteration=10,tolerence=10e-8,epsilon=10e-8):
        self.lr=lr
        self.max_iteration=max_iteration
        self.epsilon=epsilon
        self.tolerence=tolerence
        
    #hypothesis : logistic sigmoid function
    def sigmoid(self,X,theta):
        #s=1/(1 + np.exp(-1*(X@theta)))
        #print('sigmoid',s)
        z = X@theta
        #print('z', z.shape)
        return 1/(1 + np.exp(-z))
    
    # compute the grandient  
    def get_gradientB(self,X,y,theta):
        #return (1/len(X))*np.sum(( self.sigmoid(X,theta) - y)*X)
        h   = self.sigmoid(X,theta)
        return np.dot(X.T, (h - y))
    
    def get_gradientS(self,X,y,theta):
        return (1/len(X))*np.sum(( self.sigmoid(X,theta) - y)*X)
        #h   = self.sigmoid(X,theta)
        #return np.dot(X.T, (h - y))
    
    #compute the loss
    def loss(self,X,y,theta):
        return   (-y*np.log(self.sigmoid(X,theta))  - (1-y)*np.log(1- self.sigmoid(X,theta))).mean()
#         return   np.sum(((-1)*y*np.log(self.sigmoid(X,theta))  - (1-y)*np.log(1- self.sigmoid(X,theta))))

    def hessian(self,X,theta):
        s=self.sigmoid(X,theta)
        ds=1-s
        diago=np.diag(s.T@ds)
        diago=diago.reshape(-1,1)
        #print('shape of sig',s.shape)
        #print('shape of x',X.shape)
        #print('shape of x transpose',X.T.shape)
        #print('shape of 1-sig',ds.shape)
        #print('shape of diago',diago.shape)
        #return ((X@X.T)@s)@ds.T + self.epsilon*np.eye(X.shape[0])
        #return (((X.T@s)@ds.T)@X) +   self.epsilon*np.eye(X.T.shape[0]) 
        return (X.T*diago)@X
    
    #Batch grediant descent
    def fit_BGD(self,X,y):
        
        #make a copy of our data
        X_copy=X.copy()
        
         #add the intercept column
        intercept=np.ones((X_copy.shape[0],1))
        X_copy=np.concatenate((intercept,X_copy),axis=1)
        #print('shape of the whole x',X_copy.shape)
        
        #initialise the weight
        self.theta=np.zeros((X_copy.shape[1],1))
        #print('shape of theta',theta.shape)
        
        for i in range(self.max_iteration):
            #compute the gradient
            grad = self.get_gradientB(X_copy, y, self.theta)#.reshape(-1,1)
            #update the weight
            self.theta = self.theta - self.lr*grad
            #print('my update',theta)
            #print the value of the loss
            #print('the loss function is ',self.loss(X_copy,y,self.theta))
            
            
    #stochastic gradient descent        
    def fit_SGD(self,X,y):
        
        #make a copy of our data
        X_copy=X.copy()
        
         #add the intercept column
        intercept=np.ones((X_copy.shape[0],1))
        X_copy=np.concatenate((intercept,X_copy),axis=1)
        #print('shape of the whole x',X_copy.shape)
        
        #initialise the weight
        self.theta=np.zeros((X_copy.shape[1],1))
        #print('shape of theta',theta.shape)
        
        for i in range(self.max_iteration):
            random_vector=np.random.permutation(X_copy.shape[0])
            for j in random_vector:
                
                #compute the gradient
                grad = self.get_gradientS(X_copy[j], y[j], self.theta)#.reshape(-1,1)
                #update the weight
                self.theta = self.theta - self.lr*grad.reshape(-1,1)
                #print('my update',theta)
                #print the value of the loss
                print('the loss function is ',self.loss(X_copy[j],y[j],self.theta))
                
        
        
    def newton_method(self,X,y):
        #make a coy of X
        X_copy=X.copy()
        #add the intercept
        
        intercept=np.ones((X_copy.shape[0],1))
        X_copy=np.concatenate((intercept,X_copy),axis=1)
        
        #initialize the weight
        self.theta=np.zeros((X_copy.shape[1],1))
        diff=1
        current_iter=1
        while diff >= self.tolerence and current_iter<self.max_iteration:
            H=self.hessian(X_copy,self.theta)
            inv_H=np.linalg.inv(H)
            grad=self.get_gradientS( X_copy,y, self.theta)
            grad=grad.reshape(-1,1)
            prev_theta=self.theta.copy()
            self.theta = self.theta - inv_H*grad
            cur_theta=self.theta.copy()
            diff=np.linalg.norm(prev_theta - cur_theta)
            current_iter+=1
            #print('theta is ',self.theta)
            print('the loss is',self.loss(X_copy,y,self.theta))
        
        
        

    def predict(self,X):
        X_copy=X.copy()
        
        print('shape of theta',self.theta.shape)
        intercept=np.ones((X_copy.shape[0],1))
        print('shape of x copy' ,X_copy.shape)
        print('shape of intercept' ,intercept.shape)
        X_copy=np.concatenate((intercept, X_copy), axis=1)
        print('shape',X_copy.shape)
        
        return self.sigmoid(X_copy,self.theta)
    
    def error_prediction(self,X,y_true):
        X_copy=X.copy()
        
        #print('shape of theta',self.theta.shape)
        intercept=np.ones((X_copy.shape[0],1))
        #print('shape of x copy' ,X_copy.shape)
        #print('shape of intercept' ,intercept.shape)
        X_copy=np.concatenate((intercept, X_copy), axis=1)
        #print('shape',X_copy.shape) 
        y_hat = (self.sigmoid(X_copy,self.theta) > 0.5).astype(int)
        return np.sum(y_hat == y_true.reshape(-1,1)) / len(y_true)

# %%
logistic=LogisticRegresion(lr=0.01,max_iteration=5)

# %%
logistic.newton_method(X_train,y_train)
# Out:
# the loss is 0.6931151187775165
# the loss is 0.6930831341238868
# the loss is 0.6930512265564273
# the loss is 0.6930193960324614

# %%
logistic.fit_BGD(X_train,y_train)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: overflow encountered in exp

# %%
logistic.fit_SGD(X_train,y_train)
# Out:
# the loss function is  0.6931254894204432
# the loss function is  0.6931254683110236
# the loss function is  0.6931163579592154
# the loss function is  0.6931210798895758
# the loss function is  0.6929065530829528
# the loss function is  0.69325105485911
# the loss function is  0.69309032481549
# the loss function is  0.6932108306201891
# the loss function is  0.6930812313332524
# the loss function is  0.6932053438914848
# the loss function is  0.6930661345301761
# the loss function is  0.6929743589392088
# the loss function is  0.693256609615668
# the loss function is  0.6930476255361204
# the loss function is  0.6930542345311782
# the loss function is  0.6930267360018425
# the loss function is  0.69294317775987
# the loss function is  0.6934339061819769
# the loss function is  0.6932209392543147
# the loss function is  0.6930655704592288
# the loss function is  0.6929546470928617
# the loss function is  0.6932526354694216
# the loss function is  0.6932220079836351
# the loss function is  0.6932050285320792
# the loss function is  0.6930941376984572
# the loss function is  0.6931135903869219
# the loss function is  0.6931024053450392
# the loss function is  0.693029815489313
# the loss function is  0.6932075570935529
# the loss function is  0.693162519852024
# the loss function is  0.6931409728586442
# the loss function is  0.6931224625140991
# the loss function is  0.6931479655458057
# the loss function is  0.6930824835306792
# the loss function is  0.6931635958990328
# the loss function is  0.6930950752135785
# the loss function is  0.693168673683507
# the loss function is  0.693108782798427
# the loss function is  0.6931677387328276
# the loss function is  0.6931361191482195
# the loss function is  0.6931243235507144
# the loss function is  0.6931374652255012
# the loss function is  0.6931287509951795
# the loss function is  0.6931113100410313
# the loss function is  0.6929927461260509
# the loss function is  0.693078019071437
# the loss function is  0.6932218846651406
# the loss function is  0.6931970155870929
# the loss function is  0.6930603190251989
# the loss function is  0.6932086753746954
# the loss function is  0.6930956561643318
# the loss function is  0.6931746840308145
# the loss function is  0.6930350783802866
# the loss function is  0.6930009691925735
# the loss function is  0.6928523245619652
# the loss function is  0.6933136416952397
# the loss function is  0.6932693307516204
# the loss function is  0.6930582307910824
# the loss function is  0.6930571799961811
# the loss function is  0.6928013280050819
# the loss function is  0.6929200006184163
# the loss function is  0.6929119913380665
# the loss function is  0.6929040980550462
# the loss function is  0.6933434610069026
# the loss function is  0.6928684294785483
# the loss function is  0.6927507134421903
# the loss function is  0.6933920370332918
# the loss function is  0.6928968188363065
# the loss function is  0.6936085885974276
# the loss function is  0.6928477940582518
# the loss function is  0.6929173070287316
# the loss function is  0.6936658139822315
# the loss function is  0.6928927694307233
# the loss function is  0.6934996996798543
# the loss function is  0.6933142519613956
# the loss function is  0.6928473119704986
# the loss function is  0.6928643330384648
# the loss function is  0.6933757723730567
# the loss function is  0.6934692437152743
# the loss function is  0.6929725839102199
# the loss function is  0.6929794209849189
# the loss function is  0.692869303905408
# the loss function is  0.693600937156533
# the loss function is  0.6933347631854093
# the loss function is  0.6933072205107892
# the loss function is  0.6928736760730569
# the loss function is  0.6928626690332776
# the loss function is  0.6934542553913206
# the loss function is  0.6933033613252578
# the loss function is  0.693274548740215
# the loss function is  0.6931109494330333
# the loss function is  0.6930092667849211
# the loss function is  0.6928584300223851
# the loss function is  0.6930406984057419
# the loss function is  0.6934796844643883
# the loss function is  0.6930030952442092
# the loss function is  0.6932711475032195
# the loss function is  0.6930175518560486
# the loss function is  0.6930423182735443
# the loss function is  0.6933703002814089
# the loss function is  0.6929496039541562
# the loss function is  0.6930922911741051
# the loss function is  0.6932574880077718
# the loss function is  0.6930250423522363
# the loss function is  0.6933620263623828
# the loss function is  0.6930920518607023
# the loss function is  0.6932205229612262
# the loss function is  0.6930963561071605
# the loss function is  0.693242752341675
# the loss function is  0.6931645680480434
# the loss function is  0.6931014616758517
# the loss function is  0.6931585103930331
# the loss function is  0.6931016144625101
# the loss function is  0.69315996677119
# the loss function is  0.6931030096342219
# the loss function is  0.693161830242256
# the loss function is  0.6931422205969376
# the loss function is  0.6930218440861892
# the loss function is  0.6930685926770472
# the loss function is  0.6931961269544596
# the loss function is  0.692989116445739
# the loss function is  0.6932260609459807
# the loss function is  0.693098038763941
# the loss function is  0.6932073867810388
# the loss function is  0.6930701252914089
# the loss function is  0.6930285130643793
# the loss function is  0.6930108144705898
# the loss function is  0.6932239472599188
# the loss function is  0.6930118878416568
# the loss function is  0.693266818404966
# the loss function is  0.6930242039088196
# the loss function is  0.6932895711399397
# the loss function is  0.6929471738503715
# the loss function is  0.6932753080783417
# the loss function is  0.6929949081860328
# the loss function is  0.6929622290370674
# the loss function is  0.6929908753266055
# the loss function is  0.6934662969858312
# the loss function is  0.6930377751106774
# the loss function is  0.6929735452824458
# the loss function is  0.6932675328749702
# the loss function is  0.6932535274685957
# the loss function is  0.6930292736039687
# the loss function is  0.6933065387122217
# the loss function is  0.6930331931054652
# the loss function is  0.6929903847632864
# the loss function is  0.6926788185544772
# the loss function is  0.6928849980253688
# the loss function is  0.6935327533816098
# the loss function is  0.6933769510064482
# the loss function is  0.6930320584898358
# the loss function is  0.6929764929888853
# the loss function is  0.6929256130914292
# the loss function is  0.692927860911644
# the loss function is  0.6928390985445845
# the loss function is  0.6934548260240322
# the loss function is  0.6934709360737241
# the loss function is  0.6929316918035744
# the loss function is  0.6928741708405132
# the loss function is  0.6934023851426756
# the loss function is  0.6925666985999447
# the loss function is  0.6928432014967879
# the loss function is  0.6935358974483655
# the loss function is  0.6933544637851288
# the loss function is  0.6933618181668619
# the loss function is  0.692828128706264
# the loss function is  0.6928152133941474
# the loss function is  0.6928361537331404
# the loss function is  0.6934138151748672
# the loss function is  0.6933834726238755
# the loss function is  0.6928923283780966
# the loss function is  0.6928730849079603
# the loss function is  0.6936467378729114
# the loss function is  0.6928629626315583
# the loss function is  0.6928556045025951
# the loss function is  0.6928260142405934
# the loss function is  0.692891559962207
# the loss function is  0.69284651900171
# the loss function is  0.6928243233940691
# the loss function is  0.6926874860592758
# the loss function is  0.6936626501814634
# the loss function is  0.6925236241544349
# the loss function is  0.693619855355806
# the loss function is  0.6938628312098895
# the loss function is  0.6926447268963725
# the loss function is  0.6934576200692993
# the loss function is  0.6934238338788886
# the loss function is  0.6928480028018589
# the loss function is  0.6934306523814515
# the loss function is  0.6928471460777618
# the loss function is  0.6923067702735962
# the loss function is  0.6926111041510499
# the loss function is  0.6925080568936042
# the loss function is  0.6935187601022502
# the loss function is  0.6925744836364403
# the loss function is  0.692260213414532
# the loss function is  0.6925228010884673
# the loss function is  0.6936550082786047
# the loss function is  0.6926257960424328
# the loss function is  0.6926173262975269
# the loss function is  0.6926023368831105
# the loss function is  0.6923559859923561
# the loss function is  0.6924366501644564
# the loss function is  0.6923609253131646
# the loss function is  0.6940412215215187
# the loss function is  0.6920771141949178
# the loss function is  0.6939131925094947
# the loss function is  0.6923359605828102
# the loss function is  0.6937159339145996
# the loss function is  0.6923808769236619
# the loss function is  0.6925238758293389
# the loss function is  0.6922891122848821
# the loss function is  0.6924492844866939
# the loss function is  0.6939904405458707
# the loss function is  0.6920916152768217
# the loss function is  0.6942794933805831
# the loss function is  0.6943165232215612
# the loss function is  0.6924830450510877
# the loss function is  0.6919801957817456
# the loss function is  0.6943018791499234
# the loss function is  0.6937671131784605
# the loss function is  0.6937337857512169
# the loss function is  0.693822353467065
# the loss function is  0.692735200154473
# the loss function is  0.6925006511430727
# the loss function is  0.6925555914407389
# the loss function is  0.6925971739079773
# the loss function is  0.692072820976281
# the loss function is  0.6939666052491198
# the loss function is  0.6937291366198128
# the loss function is  0.6938620180580716
# the loss function is  0.6941763458155373
# the loss function is  0.692437590845483
# the loss function is  0.6925071853618976
# the loss function is  0.6936777690161877
# the loss function is  0.6926744895142594
# the loss function is  0.6941343532203434
# the loss function is  0.6923190681364227
# the loss function is  0.6923517527751755
# the loss function is  0.6925684352763585
# the loss function is  0.6915303182337581
# the loss function is  0.6924555561837266
# the loss function is  0.6923273451484975
# the loss function is  0.6939522075914016
# the loss function is  0.6920892136155297
# the loss function is  0.6942791079213947
# the loss function is  0.6942703176484563
# the loss function is  0.6924309383932241
# the loss function is  0.6925498779924955
# the loss function is  0.6924949399545327
# the loss function is  0.6921162594401101
# the loss function is  0.6925974348694185
# the loss function is  0.6912950490238806
# the loss function is  0.6923960862333887
# the loss function is  0.6946038992114933
# the loss function is  0.6923621632276608
# the loss function is  0.6921197695081698
# the loss function is  0.6922740366303363
# the loss function is  0.6924188888667505
# the loss function is  0.6902500569665347
# the loss function is  0.6921070198621148
# the loss function is  0.6920905473702035
# the loss function is  0.6949944281202204
# the loss function is  0.6909955133446961
# the loss function is  0.6945066774628268
# the loss function is  0.6913295340085244
# the loss function is  0.6919712843309656
# the loss function is  0.691529657379045
# the loss function is  0.6919120601797986
# the loss function is  0.6917886503833781
# the loss function is  0.6958808769505456
# the loss function is  0.6952329022645376
# the loss function is  0.6926937138722529
# the loss function is  0.6950888309579928
# the loss function is  0.6947771693800009
# the loss function is  0.6939086256571242
# the loss function is  0.6921357304109784
# the loss function is  0.6924279633185412
# the loss function is  0.6927266845548719
# the loss function is  0.692142577869251
# the loss function is  0.6922094318971997
# the loss function is  0.69393477184582
# the loss function is  0.69206543748839
# the loss function is  0.6920546336116835
# the loss function is  0.6949720917987126
# the loss function is  0.6945015436152969
# the loss function is  0.6943916010973615
# the loss function is  0.6920773767637408
# the loss function is  0.6923421590429699
# the loss function is  0.6919049678037758
# the loss function is  0.6919178482325511
# the loss function is  0.6920496893388722
# the loss function is  0.6913952093498177
# the loss function is  0.6921265084211461
# the loss function is  0.6921820834372114
# the loss function is  0.6919813005381711
# the loss function is  0.6911575520807095
# the loss function is  0.6920496200363371
# the loss function is  0.6920521652261062
# the loss function is  0.6950128084654198
# the loss function is  0.6923783369649569
# the loss function is  0.6970777182635208
# the loss function is  0.6919897825860664
# the loss function is  0.6924639053260144
# the loss function is  0.6915195257850495
# the loss function is  0.6948033182270275
# the loss function is  0.691759075937372
# the loss function is  0.6915420748377485
# the loss function is  0.6921690978231856
# the loss function is  0.6918700211569275
# the loss function is  0.6914867982934488
# the loss function is  0.6920417391062215
# the loss function is  0.6916546955803705
# the loss function is  0.6916102125433276
# the loss function is  0.6916794764797782
# the loss function is  0.6924020653284697
# the loss function is  0.6908731198189124
# the loss function is  0.6947194035427844
# the loss function is  0.6908017106042792
# the loss function is  0.6948116003493782
# the loss function is  0.6954083332676452
# the loss function is  0.6914809169255904
# the loss function is  0.6919024466398968
# the loss function is  0.6963486360360694
# the loss function is  0.692457302345432
# the loss function is  0.6944715571302376
# the loss function is  0.6947161173426293
# the loss function is  0.6946383504991349
# the loss function is  0.6953226192028068
# the loss function is  0.6952145548573991
# the loss function is  0.6913709868344701
# the loss function is  0.6942711797793032
# the loss function is  0.6920552714922689
# the loss function is  0.6940821536078001
# the loss function is  0.6944928808236662
# the loss function is  0.6953264250926577
# the loss function is  0.6919126110352617
# the loss function is  0.6914448740350918
# the loss function is  0.6948641423789553
# the loss function is  0.6918412890830662
# the loss function is  0.6917601819866456
# the loss function is  0.6920157477673462
# the loss function is  0.6944905655926832
# the loss function is  0.692155241076983
# the loss function is  0.691213685452881
# the loss function is  0.692443636003721
# the loss function is  0.6954023260366957
# the loss function is  0.6947464723729165
# the loss function is  0.6907631109625522
# the loss function is  0.6948639053595402
# the loss function is  0.6956505388899178
# the loss function is  0.6915400476576248
# the loss function is  0.6951757970549775
# the loss function is  0.6959117333888519
# the loss function is  0.6913062423470334
# the loss function is  0.6942447126709205
# the loss function is  0.6884056491567113
# the loss function is  0.6876942006779333
# the loss function is  0.691941002000422
# the loss function is  0.6917734409269768
# the loss function is  0.6920252810659961
# the loss function is  0.6913513559506924
# the loss function is  0.6919166085218025
# the loss function is  0.6888750699538646
# the loss function is  0.6912528429637398
# the loss function is  0.6951330878169775
# the loss function is  0.6920554762680794
# the loss function is  0.6917349347762995
# the loss function is  0.6914383245753251
# the loss function is  0.6959005391344244
# the loss function is  0.6913549812898149
# the loss function is  0.691233833330151
# the loss function is  0.6914842994485153
# the loss function is  0.6956443634890466
# the loss function is  0.6944167201115482
# the loss function is  0.6949374716460556
# the loss function is  0.6912567327584517
# the loss function is  0.6923182758060176
# the loss function is  0.689863818112835
# the loss function is  0.6913841047697789
# the loss function is  0.6960420475558751
# the loss function is  0.6942981309291703
# the loss function is  0.6958642729389665
# the loss function is  0.6920891015067516
# the loss function is  0.6946950154052881
# the loss function is  0.691425487486933
# the loss function is  0.6918496782639725
# the loss function is  0.6915624981207846
# the loss function is  0.6948171388465912
# the loss function is  0.6915778666238761
# the loss function is  0.6967056735409135
# the loss function is  0.6961705979169684
# the loss function is  0.6951900675012576
# the loss function is  0.6945332513149711
# the loss function is  0.6917990812935164
# the loss function is  0.6916585099394772
# the loss function is  0.6902360976341863
# the loss function is  0.6957386102487584
# the loss function is  0.6893334655811364
# the loss function is  0.6904742010465637
# the loss function is  0.6910246296672303
# the loss function is  0.6916100388662851
# the loss function is  0.6903467025868547
# the loss function is  0.6916979780720311
# the loss function is  0.6911657742554109
# the loss function is  0.6908361917485921
# the loss function is  0.6960948938727833
# the loss function is  0.6904171209341272
# the loss function is  0.6901074331941603
# the loss function is  0.6908665819475478
# the loss function is  0.6907527339852423
# the loss function is  0.6966634079039682
# the loss function is  0.6897145675652208
# the loss function is  0.6951090870719928
# the loss function is  0.691604973949145
# the loss function is  0.6950004396757443
# the loss function is  0.691562913837791
# the loss function is  0.689728836336999
# the loss function is  0.6907817865140493
# the loss function is  0.6906643672829531
# the loss function is  0.6912675180921751
# the loss function is  0.6907435425688071
# the loss function is  0.6911100806440182
# the loss function is  0.6911406898741005
# the loss function is  0.6969382266362801
# the loss function is  0.695775312716043
# the loss function is  0.6923066976980057
# the loss function is  0.6959431981402534
# the loss function is  0.6945189257131529
# the loss function is  0.6957700718609346
# the loss function is  0.6914129834022396
# the loss function is  0.6894783332153364
# the loss function is  0.6917445396605691
# the loss function is  0.6924035484810791
# the loss function is  0.6945484708174459
# the loss function is  0.6951757774891302
# the loss function is  0.6910160333149804
# the loss function is  0.6912947127098615
# the loss function is  0.6949959116362214
# the loss function is  0.6902441916726183
# the loss function is  0.6913138151742604
# the loss function is  0.6891802872565829
# the loss function is  0.69909652695303
# the loss function is  0.68982435242692
# the loss function is  0.6959327979634025
# the loss function is  0.6951368903221594
# the loss function is  0.6911731194644288
# the loss function is  0.6953560792763476
# the loss function is  0.6895004495257142
# the loss function is  0.690131531834117
# the loss function is  0.6910670055970772
# the loss function is  0.6965490221669167
# the loss function is  0.6911388566598953
# the loss function is  0.6957341824855173
# the loss function is  0.6912686532206654
# the loss function is  0.689498381845307
# the loss function is  0.690299933991573
# the loss function is  0.6904672837375279
# the loss function is  0.6910764193929786
# the loss function is  0.6914279714200295
# the loss function is  0.691036406635261
# the loss function is  0.6955977627836675
# the loss function is  0.6953582058675952
# the loss function is  0.6959027388695728
# the loss function is  0.6903408086487932
# the loss function is  0.6893068165592997
# the loss function is  0.6915516410123818
# the loss function is  0.6913610803261144
# the loss function is  0.6909759389660077
# the loss function is  0.6963529741370353
# the loss function is  0.6959493856408704
# the loss function is  0.6915314199126122
# the loss function is  0.6900129517525574
# the loss function is  0.6912136476423296
# the loss function is  0.6951875563563872
# the loss function is  0.691219431177437
# the loss function is  0.6893505401669131
# the loss function is  0.6912449394583037
# the loss function is  0.6893691200572717
# the loss function is  0.6880693841830336
# the loss function is  0.6975552629816403
# the loss function is  0.6905711024294419
# the loss function is  0.6903594608185288
# the loss function is  0.6907091074494022
# the loss function is  0.6908977712184519
# the loss function is  0.6897174902835339
# the loss function is  0.6908670362142587
# the loss function is  0.6908097882509678
# the loss function is  0.6903568862539484
# the loss function is  0.7036463849717749
# the loss function is  0.6875305052242455
# the loss function is  0.6910519685380975
# the loss function is  0.6911468739979617
# the loss function is  0.6958476962524774
# the loss function is  0.6890092937161406
# the loss function is  0.6973943546399306
# the loss function is  0.6960634571668025
# the loss function is  0.6906822821691859
# the loss function is  0.6957304995703191
# the loss function is  0.6908301504899984
# the loss function is  0.6894759226141322
# the loss function is  0.6906109493716652
# the loss function is  0.6894261677904636
# the loss function is  0.6958626631514576
# the loss function is  0.6891106414575096
# the loss function is  0.6969810443238256
# the loss function is  0.6905573370607171
# the loss function is  0.6962103637490975
# the loss function is  0.6976630196322349
# the loss function is  0.6910441593525852
# the loss function is  0.6905928924369658
# the loss function is  0.68940347150657
# the loss function is  0.6899160371080126
# the loss function is  0.6901335567943214
# the loss function is  0.6903002134474169
# the loss function is  0.6901705200266924
# the loss function is  0.6908344688133975
# the loss function is  0.6905078495416129
# the loss function is  0.6894880245889214
# the loss function is  0.7002249633686687
# the loss function is  0.6909991917191309
# the loss function is  0.6910168077747733
# the loss function is  0.696360878000734
# the loss function is  0.6888244705306499
# the loss function is  0.6961341881723255
# the loss function is  0.697097257445137
# the loss function is  0.6903148290766307
# the loss function is  0.6905264886529311
# the loss function is  0.6902920479642223
# the loss function is  0.6915177465774182
# the loss function is  0.6982295164672478
# the loss function is  0.698495110077258
# the loss function is  0.6893442001802409
# the loss function is  0.6898386194385918
# the loss function is  0.6887043689061656
# the loss function is  0.6967956156743546
# the loss function is  0.6958879489963243
# the loss function is  0.6998256179000645
# the loss function is  0.6894631760703576
# the loss function is  0.6905872913468327
# the loss function is  0.6908448100332744
# the loss function is  0.6977575266710756
# the loss function is  0.6980019904682533
# the loss function is  0.6908468363483856
# the loss function is  0.6901741249425357
# the loss function is  0.6913895672723385
# the loss function is  0.6887990316346028
# the loss function is  0.6888715173516846
# the loss function is  0.6898282952234556
# the loss function is  0.6899726377222233
# the loss function is  0.6914596720372048
# the loss function is  0.6962028492802665
# the loss function is  0.6896107376914944
# the loss function is  0.6962487944008469
# the loss function is  0.6899326978427839
# the loss function is  0.6895390000248187
# the loss function is  0.6909105727092407
# the loss function is  0.6908476395023149
# the loss function is  0.6892815816729368
# the loss function is  0.6884272148443695
# the loss function is  0.7022387947426708
# the loss function is  0.6896256786937756
# the loss function is  0.6947640287447975
# the loss function is  0.6893501565538609
# the loss function is  0.6908503673574464
# the loss function is  0.6884885114887579
# the loss function is  0.6902527057614702
# the loss function is  0.6985383569332192
# the loss function is  0.6960909612452504
# the loss function is  0.6884827127700077
# the loss function is  0.6902989942012705
# the loss function is  0.6891547832355243
# the loss function is  0.6902024110635104
# the loss function is  0.6870947959186786
# the loss function is  0.6977281497693463
# the loss function is  0.6895581081825987
# the loss function is  0.6900696812798295
# the loss function is  0.6900900216254858
# the loss function is  0.6865229965036269
# the loss function is  0.689386782611238
# the loss function is  0.6991338625452678
# the loss function is  0.6893373214162842
# the loss function is  0.6957541454006868
# the loss function is  0.6904326027815493
# the loss function is  0.6960089739450169
# the loss function is  0.6878236625660056
# the loss function is  0.689104195522589
# the loss function is  0.6894511468368971
# the loss function is  0.6901381197937353
# the loss function is  0.6987488317389788
# the loss function is  0.6967821823338705
# the loss function is  0.6885064605521136
# the loss function is  0.6889629991172902
# the loss function is  0.6891208697550105
# the loss function is  0.6878042632338649
# the loss function is  0.6860576562971018
# the loss function is  0.7029291702393003
# the loss function is  0.6888760929367101
# the loss function is  0.6864153667765779
# the loss function is  0.6992628541324136
# the loss function is  0.6952410023570872
# the loss function is  0.690084985587393
# the loss function is  0.6895181415184296
# the loss function is  0.6951874799663524
# the loss function is  0.6909975898026337
# the loss function is  0.6878038684276498
# the loss function is  0.6960233353576967
# the loss function is  0.6889178542053613
# the loss function is  0.6965740469666026
# the loss function is  0.6890182806806501
# the loss function is  0.6894996972293926
# the loss function is  0.6896030325455889
# the loss function is  0.6891708315478704
# the loss function is  0.6898459896482021
# the loss function is  0.6897520279040495
# the loss function is  0.6899321063727888
# the loss function is  0.7010741306203122
# the loss function is  0.7011781976869172
# the loss function is  0.6974136856740313
# the loss function is  0.6885884903297902
# the loss function is  0.6895760180310248
# the loss function is  0.689429495678863
# the loss function is  0.686681677412604
# the loss function is  0.696640617853861
# the loss function is  0.6903592082689677
# the loss function is  0.6964706328364213
# the loss function is  0.6892202750834346
# the loss function is  0.6868419514071789
# the loss function is  0.6987865846009326
# the loss function is  0.6902475027624682
# the loss function is  0.68687146662094
# the loss function is  0.7009822335101332
# the loss function is  0.6892541190672513
# the loss function is  0.6884039747532588
# the loss function is  0.6900565800262506
# the loss function is  0.6904043905851178
# the loss function is  0.6892556065182663
# the loss function is  0.6986985438825698
# the loss function is  0.689235538648245
# the loss function is  0.6894907197919251
# the loss function is  0.6966493701718212
# the loss function is  0.7008778765529275
# the loss function is  0.6896763310223886
# the loss function is  0.704509680225183
# the loss function is  0.6978597142209892
# the loss function is  0.6972629502490569
# the loss function is  0.6890490921224274
# the loss function is  0.7016420106164006
# the loss function is  0.6972853266226577
# the loss function is  0.6886063215336443
# the loss function is  0.6973564414699336
# the loss function is  0.6880189072364595
# the loss function is  0.6876263197414522
# the loss function is  0.6969924201736417
# the loss function is  0.6873280721812007
# the loss function is  0.6901277598917606
# the loss function is  0.6968420194593153
# the loss function is  0.6895451751098579
# the loss function is  0.6981014768768808
# the loss function is  0.6905089854415736
# the loss function is  0.689501308604158
# the loss function is  0.6971251136884272
# the loss function is  0.6884370274245117
# the loss function is  0.6894138086692749
# the loss function is  0.6992210356009255
# the loss function is  0.6882009401686155
# the loss function is  0.7016623929914906
# the loss function is  0.6889711782858375
# the loss function is  0.6876856850915701
# the loss function is  0.6886231720171219
# the loss function is  0.6956164645050832
# the loss function is  0.6972248209978056
# the loss function is  0.698816840936174
# the loss function is  0.7020825511948126
# the loss function is  0.6894929835233865
# the loss function is  0.6888164789337247
# the loss function is  0.6998688500167899
# the loss function is  0.6854734422609118
# the loss function is  0.6906402473791885
# the loss function is  0.6901339134411599
# the loss function is  0.6866351386147037
# the loss function is  0.6891249462127695
# the loss function is  0.68857389415369
# the loss function is  0.6899716599724518
# the loss function is  0.6863434144992961
# the loss function is  0.6892182380304519
# the loss function is  0.7040039940925319
# the loss function is  0.696475983592957
# the loss function is  0.6893108722337027
# the loss function is  0.686937163270073
# the loss function is  0.689722295047201
# the loss function is  0.7004578151829656
# the loss function is  0.6878591261636205
# the loss function is  0.6900789313911321
# the loss function is  0.6886747106501353
# the loss function is  0.6992425586824339
# the loss function is  0.687858777069472
# the loss function is  0.6895259667927388
# the loss function is  0.6884863645908545
# the loss function is  0.6999090516634004
# the loss function is  0.6895901335769038
# the loss function is  0.6890458698331047
# the loss function is  0.6824956061357936
# the loss function is  0.6977987352699033
# the loss function is  0.6998860976377314
# the loss function is  0.6974289910946971
# the loss function is  0.6873367709445267
# the loss function is  0.6896005358136026
# the loss function is  0.700897926826731
# the loss function is  0.6979445455817056
# the loss function is  0.6857124010320315
# the loss function is  0.6967860870716516
# the loss function is  0.689373521397428
# the loss function is  0.6883475384259551
# the loss function is  0.6976201720669727
# the loss function is  0.689401514540255
# the loss function is  0.6879204918439593
# the loss function is  0.6983056105826835
# the loss function is  0.6874490107549843
# the loss function is  0.6874538064733605
# the loss function is  0.687862704832493
# the loss function is  0.6984527769204583
# the loss function is  0.690067798249991
# the loss function is  0.689809751326383
# the loss function is  0.6898512234337569
# the loss function is  0.6901777488834081
# the loss function is  0.6894567459615659
# the loss function is  0.7019275657366866
# the loss function is  0.6857219640113307
# the loss function is  0.6890889910205258
# the loss function is  0.6903990540738396
# the loss function is  0.6886004358730323
# the loss function is  0.688794920979158
# the loss function is  0.6894966982305697
# the loss function is  0.6885066279665097
# the loss function is  0.6895195911219584
# the loss function is  0.6893933137100806
# the loss function is  0.6891415176924421
# the loss function is  0.6795887058538419
# the loss function is  0.6890985069037446
# the loss function is  0.6896678013588269
# the loss function is  0.6877893578850278
# the loss function is  0.6961540187451509
# the loss function is  0.6867806458644489
# the loss function is  0.6999301324091969
# the loss function is  0.6968654746064037
# the loss function is  0.7072602442482996
# the loss function is  0.6870338642953812
# the loss function is  0.6960851616111762
# the loss function is  0.6900649068358691
# the loss function is  0.6972772412182
# the loss function is  0.6895328903847002
# the loss function is  0.7015763452823325
# the loss function is  0.6900715677631669
# the loss function is  0.6995968751813982
# the loss function is  0.689491579827795
# the loss function is  0.6899587666645964
# the loss function is  0.6893285343329046
# the loss function is  0.6980592824608242
# the loss function is  0.6974894276758413
# the loss function is  0.682933413380113
# the loss function is  0.7011186663990657
# the loss function is  0.6901496513140455
# the loss function is  0.6969646263101543
# the loss function is  0.6963034780880986
# the loss function is  0.6885936227365068
# the loss function is  0.6879337339346465
# the loss function is  0.6881865078286007
# the loss function is  0.6880717274388696
# the loss function is  0.6979408057768142
# the loss function is  0.689808622236552
# the loss function is  0.6973118334187618
# the loss function is  0.6875416249608826
# the loss function is  0.7004398717521539
# the loss function is  0.6863810545861607
# the loss function is  0.6894581181514668
# the loss function is  0.6826735570748494
# the loss function is  0.7044044753659993
# the loss function is  0.6892309726092418
# the loss function is  0.6878000592732547
# the loss function is  0.6849960787173726
# the loss function is  0.6861856548049261
# the loss function is  0.6894820257348083
# the loss function is  0.6988372909816154
# the loss function is  0.6977187878129848
# the loss function is  0.7015530675656384
# the loss function is  0.6898954328761995
# the loss function is  0.6884985557664193
# the loss function is  0.6888883587053681
# the loss function is  0.699633657557096
# the loss function is  0.6891474211720029
# the loss function is  0.6866838971038296
# the loss function is  0.7007733413131565
# the loss function is  0.7008625450419794
# the loss function is  0.7000192474175145
# the loss function is  0.6884738102051422
# the loss function is  0.6878703969703606
# the loss function is  0.6862469563590239
# the loss function is  0.6844006747487736
# the loss function is  0.6877259100643102
# the loss function is  0.6853853125690583
# the loss function is  0.6868146377374881
# the loss function is  0.6877677533849772
# the loss function is  0.6994898310131634
# the loss function is  0.6858477082871492
# the loss function is  0.687305252996856
# the loss function is  0.68450032324946
# the loss function is  0.6980364023971717
# the loss function is  0.6891798030902349
# the loss function is  0.6997930639929305
# the loss function is  0.6987460097153748
# the loss function is  0.6820916234798885
# the loss function is  0.6882111585065432
# the loss function is  0.6884734088706287
# the loss function is  0.6965142833253491
# the loss function is  0.6884945289469986
# the loss function is  0.7022958076374605
# the loss function is  0.6782094963042625
# the loss function is  0.7005212011068312
# the loss function is  0.6873063358777549
# the loss function is  0.7030416488733517
# the loss function is  0.7034712831344644
# the loss function is  0.7021127940374885
# the loss function is  0.6978551149111565
# the loss function is  0.7008637573012432
# the loss function is  0.6975796940033314
# the loss function is  0.6998796232402763
# the loss function is  0.6877256110269077
# the loss function is  0.6990146844050167
# the loss function is  0.6973366423408405
# the loss function is  0.6896856156437179
# the loss function is  0.7037705192118617
# the loss function is  0.6976852766627293
# the loss function is  0.6972265375835377
# the loss function is  0.685987395725139
# the loss function is  0.7012824393865503
# the loss function is  0.6874676887748542
# the loss function is  0.690563296258342
# the loss function is  0.6995845658413553
# the loss function is  0.6863746671250185
# the loss function is  0.6901671741081555
# the loss function is  0.6832042184532982
# the loss function is  0.6874096968188583
# the loss function is  0.6862694594849877
# the loss function is  0.7020988987204448
# the loss function is  0.7020960185915748
# the loss function is  0.6882050768263641
# the loss function is  0.698844387777374
# the loss function is  0.6888072786537353
# the loss function is  0.6995933554109331
# the loss function is  0.6995538359182445
# the loss function is  0.6970183272372975
# the loss function is  0.6889223223940165
# the loss function is  0.6985653033995499
# the loss function is  0.6887959672732464
# the loss function is  0.6877103903841267
# the loss function is  0.6982924350787924
# the loss function is  0.6887203336176162
# the loss function is  0.6873628226084818
# the loss function is  0.684971614127004
# the loss function is  0.6884384276948734
# the loss function is  0.6885977316168251
# the loss function is  0.6981019162475971
# the loss function is  0.6908227906655059
# the loss function is  0.6986802607431056
# the loss function is  0.6881823932329443
# the loss function is  0.689944386897429
# the loss function is  0.7008651585674418
# the loss function is  0.6868828889301729
# the loss function is  0.6990598737629672
# the loss function is  0.6976049785777533
# the loss function is  0.6893496786082504
# the loss function is  0.6890752518807458
# the loss function is  0.6870208946601283
# the loss function is  0.6870843738317012
# the loss function is  0.6879752784609324
# the loss function is  0.6889761266650192
# the loss function is  0.686431918774649
# the loss function is  0.7083098069207293
# the loss function is  0.6894316953877455
# the loss function is  0.690084347774963
# the loss function is  0.6878312643959436
# the loss function is  0.7034650065933333
# the loss function is  0.6886237283876756
# the loss function is  0.6871509856455825
# the loss function is  0.68931560657045
# the loss function is  0.6886480688521661
# the loss function is  0.6857334975147878
# the loss function is  0.6891454382142123
# the loss function is  0.6868238150441115
# the loss function is  0.7018372248526172
# the loss function is  0.6835001037078947
# the loss function is  0.6991538180476736
# the loss function is  0.6882605364800137
# the loss function is  0.6906951307125273
# the loss function is  0.688546703396164
# the loss function is  0.6873274669331884
# the loss function is  0.698389654183245
# the loss function is  0.68886735883139
# the loss function is  0.6872023540664053
# the loss function is  0.6886145065774592
# the loss function is  0.6892091144902468
# the loss function is  0.6884054015822285
# the loss function is  0.688055643881645
# the loss function is  0.6975723984101194
# the loss function is  0.7013726198853618
# the loss function is  0.6878374605098511
# the loss function is  0.6881911081080878
# the loss function is  0.6887367556590412
# the loss function is  0.7028489058540897
# the loss function is  0.6887690123355324
# the loss function is  0.6907880755401224
# the loss function is  0.6893817965140316
# the loss function is  0.7022487933042324
# the loss function is  0.6883045111068575
# the loss function is  0.7016938978285912
# the loss function is  0.6890346860052788
# the loss function is  0.6893620700558005
# the loss function is  0.6884088635991661
# the loss function is  0.6877553517806904
# the loss function is  0.6881202965741897
# the loss function is  0.6989818427539523
# the loss function is  0.6889186050703242
# the loss function is  0.6892692611621747
# the loss function is  0.6851981954745283
# the loss function is  0.6872548924028319
# the loss function is  0.6868916407590033
# the loss function is  0.6840496470063907
# the loss function is  0.6986835643300077
# the loss function is  0.6877263472757825
# the loss function is  0.6871058198021969
# the loss function is  0.6891993164703214
# the loss function is  0.697890821311219
# the loss function is  0.6847135870265839
# the loss function is  0.6872104517525363
# the loss function is  0.7018766945536073
# the loss function is  0.7023785999384371
# the loss function is  0.7015089134545758
# the loss function is  0.6884085075198071
# the loss function is  0.6888673569546637
# the loss function is  0.7052491863347948
# the loss function is  0.6886014674873566
# the loss function is  0.6881301369265961
# the loss function is  0.714603662808653
# the loss function is  0.7011740594064322
# the loss function is  0.6839165146329488
# the loss function is  0.6978011869197762
# the loss function is  0.7016443556162398
# the loss function is  0.6853261477400521
# the loss function is  0.684926827709445
# the loss function is  0.6966905590823661
# the loss function is  0.6849853473964863
# the loss function is  0.6864842775371697
# the loss function is  0.6895984209760413
# the loss function is  0.6976262633041583
# the loss function is  0.6878448144192292
# the loss function is  0.699398709294186
# the loss function is  0.6880856955210625
# the loss function is  0.6992108359863913
# the loss function is  0.705523633480814
# the loss function is  0.6979833390733713
# the loss function is  0.6972991271760247
# the loss function is  0.6858677671619144
# the loss function is  0.6883742612503059
# the loss function is  0.6903404365508116
# the loss function is  0.6858987902680516
# the loss function is  0.6989893894748344
# the loss function is  0.6997804074198234
# the loss function is  0.6902011372551249
# the loss function is  0.7015108105369487
# the loss function is  0.6904394393996984
# the loss function is  0.6986658570276914
# the loss function is  0.6875220384037569
# the loss function is  0.7012818107197273
# the loss function is  0.6870038347482341
# the loss function is  0.6885278253515751
# the loss function is  0.7053779300107599
# the loss function is  0.6987525987965216
# the loss function is  0.6862744027171721
# the loss function is  0.6875949605531019
# the loss function is  0.6891013892795781
# the loss function is  0.6997573584772088
# the loss function is  0.701346233412429
# the loss function is  0.6882808092192918
# the loss function is  0.6884323528522154
# the loss function is  0.7008242544179524
# the loss function is  0.6845712500552024
# the loss function is  0.688396611630797
# the loss function is  0.6867432904647984
# the loss function is  0.7018052596037948
# the loss function is  0.686722496342739
# the loss function is  0.708755018378708
# the loss function is  0.7075695110396052
# the loss function is  0.6880740673265673
# the loss function is  0.6885536440948878
# the loss function is  0.7038869278452712
# the loss function is  0.6862394842939943
# the loss function is  0.6884799640121856
# the loss function is  0.6879714199760263
# the loss function is  0.7011131976396513
# the loss function is  0.6880683743121494
# the loss function is  0.6895004525510221
# the loss function is  0.6987300925845625
# the loss function is  0.6892809762926192
# the loss function is  0.688953602546136
# the loss function is  0.6892483616720645
# the loss function is  0.7040131986188779
# the loss function is  0.6880392403128999
# the loss function is  0.698338348536299
# the loss function is  0.6883083818896323
# the loss function is  0.6865290805235301
# the loss function is  0.6887876534507804
# the loss function is  0.6871765392709326
# the loss function is  0.6871136743660271
# the loss function is  0.6883323625098092
# the loss function is  0.68657669508831
# the loss function is  0.6843186272232656
# the loss function is  0.6809979343107115
# the loss function is  0.6876171535477165
# the loss function is  0.6982518364986697
# the loss function is  0.6870770888782991
# the loss function is  0.6885910139918345
# the loss function is  0.6778532935793199
# the loss function is  0.6875062647947912
# the loss function is  0.6875649054851548
# the loss function is  0.6872215632636243
# the loss function is  0.689213110952948
# the loss function is  0.6865237138805188
# the loss function is  0.681923991175926
# the loss function is  0.7023416638937848
# the loss function is  0.7088330290960877
# the loss function is  0.6909482514765284
# the loss function is  0.6845236934290417
# the loss function is  0.6879457746649705
# the loss function is  0.7030497982425756
# the loss function is  0.6717779803988803
# the loss function is  0.6864260618560627
# the loss function is  0.6877426133611126
# the loss function is  0.7028789614021276
# the loss function is  0.6979469630262002
# the loss function is  0.7023635406623561
# the loss function is  0.6833654347405018
# the loss function is  0.6964126338207144
# the loss function is  0.6908461893150081
# the loss function is  0.678032759432553
# the loss function is  0.6875498438873546
# the loss function is  0.6874231535822362
# the loss function is  0.689680317680387
# the loss function is  0.6834974515411698
# the loss function is  0.6868318535105548
# the loss function is  0.6881552954156482
# the loss function is  0.6873641792943777
# the loss function is  0.7054475118455324
# the loss function is  0.7097170913721664
# the loss function is  0.6850401431050004
# the loss function is  0.7052528566456304
# the loss function is  0.6974648476970302
# the loss function is  0.6889759355412535
# the loss function is  0.68402578872937
# the loss function is  0.6875905200678214
# the loss function is  0.7012765188892117
# the loss function is  0.6864395334925938
# the loss function is  0.6850410201925662
# the loss function is  0.7007752299641703
# the loss function is  0.6861697612879764
# the loss function is  0.7025957543075728
# the loss function is  0.7063460399014617
# the loss function is  0.6875715610306737
# the loss function is  0.6981281955863187
# the loss function is  0.6981982671403141
# the loss function is  0.6875112183111878
# the loss function is  0.6993601838050836
# the loss function is  0.6993335386864264
# the loss function is  0.7000890340398739
# the loss function is  0.6867209229263929
# the loss function is  0.6883610664729549
# the loss function is  0.6884792521242461
# the loss function is  0.6861410868823498
# the loss function is  0.6869831247251403
# the loss function is  0.6869270463733401
# the loss function is  0.684787219338434
# the loss function is  0.7018730150584994
# the loss function is  0.705697882177899
# the loss function is  0.6870256156408424
# the loss function is  0.6846095625899004
# the loss function is  0.686527366828028
# the loss function is  0.6884004594803317
# the loss function is  0.6874238044017478
# the loss function is  0.6864195550660448
# the loss function is  0.7021637820500525
# the loss function is  0.6887532434325283
# the loss function is  0.6865980444650076
# the loss function is  0.6870647297718936
# the loss function is  0.6822238974383072
# the loss function is  0.7010648608200668
# the loss function is  0.6879376512996818
# the loss function is  0.7025996330877485
# the loss function is  0.6899398750244837
# the loss function is  0.6857892004874293
# the loss function is  0.6870485309568555
# the loss function is  0.6876558969329898
# the loss function is  0.7014381361159496
# the loss function is  0.7116499798674766
# the loss function is  0.7035727564979396
# the loss function is  0.6879476465231887
# the loss function is  0.6867916868206679
# the loss function is  0.687976237808965
# the loss function is  0.6878909403396207
# the loss function is  0.6876277676029356
# the loss function is  0.6874715098561931
# the loss function is  0.6797907722069961
# the loss function is  0.6996644746903472
# the loss function is  0.6892711210551723
# the loss function is  0.68746788604406
# the loss function is  0.6991704084334077
# the loss function is  0.6855691787273525
# the loss function is  0.6881913553051275
# the loss function is  0.7003895078079418
# the loss function is  0.6873420764199849
# the loss function is  0.687565295372916
# the loss function is  0.6858973136345141
# the loss function is  0.6859085421500444
# the loss function is  0.6846189052313763
# the loss function is  0.6989455341134819
# the loss function is  0.68457218168628
# the loss function is  0.6832389576298814
# the loss function is  0.6881533576602052
# the loss function is  0.6871996949822923
# the loss function is  0.6973515170824948
# the loss function is  0.6867090827138622
# the loss function is  0.6845704214307279
# the loss function is  0.6799321575581752
# the loss function is  0.6835926594598243
# the loss function is  0.6895187880746566
# the loss function is  0.7013789953783491
# the loss function is  0.6876062640477086
# the loss function is  0.6877744832098656
# the loss function is  0.6858097135688901
# the loss function is  0.6831328074458025
# the loss function is  0.6879511289090026
# the loss function is  0.6862297701195783
# the loss function is  0.6877792449325277
# the loss function is  0.6853553085955114
# the loss function is  0.6863704258237573
# the loss function is  0.685723300413851
# the loss function is  0.686078983802509
# the loss function is  0.688565527866788
# the loss function is  0.6995943918158618
# the loss function is  0.6829180846818205
# the loss function is  0.6904087201841809
# the loss function is  0.701099613645978
# the loss function is  0.7002553928852133
# the loss function is  0.6850489241761789
# the loss function is  0.6831869934789158
# the loss function is  0.6879102092483652
# the loss function is  0.6976359760711944
# the loss function is  0.6769773638323661
# the loss function is  0.6862307510962087
# the loss function is  0.7148666059649914
# the loss function is  0.6870486270588715
# the loss function is  0.7031114728790391
# the loss function is  0.6868666264483528
# the loss function is  0.7006853086046926
# the loss function is  0.6851043192472207
# the loss function is  0.6871679428087598
# the loss function is  0.6845110459659268
# the loss function is  0.6849603838291141
# the loss function is  0.6872389030764479
# the loss function is  0.679567950137654
# the loss function is  0.6849106947741935
# the loss function is  0.6863837024061125
# the loss function is  0.7047189367802326
# the loss function is  0.6972773348928094
# the loss function is  0.7023613459019178
# ...
# the loss function is  0.6734007771461317
# the loss function is  0.6761079270522906
# the loss function is  0.6559576597442657
# the loss function is  0.6425997433204494
# the loss function is  0.6419444790345743
# the loss function is  0.6524550511482397
# the loss function is  0.7625474618395761
# the loss function is  0.6578592578567951
# the loss function is  0.6560016813452524
# the loss function is  0.6601680999023481
# the loss function is  0.724788132244775
# the loss function is  0.6590796694848079
# the loss function is  0.6658119026191576
# the loss function is  0.6659875285202763
# the loss function is  0.6449199215728944
# the loss function is  0.7668188439978004
# the loss function is  0.7504819102884847
# the loss function is  0.7361563942070397
# the loss function is  0.7534947334413933
# the loss function is  0.7329796749495933
# the loss function is  0.6593181077695798
# the loss function is  0.6553537387468572
# the loss function is  0.6593538868514893
# the loss function is  0.6600089083427891
# the loss function is  0.7438799269751044
# the loss function is  0.7594053390444356
# the loss function is  0.6428962363041189
# the loss function is  0.6308715823335218
# the loss function is  0.6647267126025619
# the loss function is  0.7465697800280615
# the loss function is  0.6437948707520312
# the loss function is  0.6650404596552639
# the loss function is  0.610639020580286
# the loss function is  0.65335589775408
# the loss function is  0.6551152298609825
# the loss function is  0.7737488363565486
# the loss function is  0.7257688019997318
# the loss function is  0.7294900577651773
# the loss function is  0.6597058284935726
# the loss function is  0.7534038685206985
# the loss function is  0.7340670625652926
# the loss function is  0.6496659928185806
# the loss function is  0.6595838399230298
# the loss function is  0.6521844334474957
# the loss function is  0.7320225078287397
# the loss function is  0.7524601097021668
# the loss function is  0.7500667323543984
# the loss function is  0.7432910756472383
# the loss function is  0.6592378437365609
# the loss function is  0.7252886945238989
# the loss function is  0.7824840775018633
# the loss function is  0.6594674307725851
# the loss function is  0.6544712603267763
# the loss function is  0.7307319114879475
# the loss function is  0.8175862868142707
# the loss function is  0.7330375176641883
# the loss function is  0.611060366956974
# the loss function is  0.6642657465461838
# the loss function is  0.6634989975054358
# the loss function is  0.7300221966881936
# the loss function is  0.8014432437147668
# the loss function is  0.7397944602962985
# the loss function is  0.6656158345238662
# the loss function is  0.65846752767939
# the loss function is  0.6447729390054779
# the loss function is  0.6517407778380635
# the loss function is  0.7850665192287396
# the loss function is  0.668213439882651
# the loss function is  0.6554815164935343
# the loss function is  0.7437130445985337
# the loss function is  0.7146306885457975
# the loss function is  0.765955588190278
# the loss function is  0.6632806747036868
# the loss function is  0.6633453812949505
# the loss function is  0.7232541167980101
# the loss function is  0.654582630352386
# the loss function is  0.6606623407970331
# the loss function is  0.759479887216806
# the loss function is  0.6362586233747842
# the loss function is  0.7367539560128654
# the loss function is  0.6583544608724288
# the loss function is  0.6613919130846246
# the loss function is  0.6641666726942429
# the loss function is  0.7730818132327676
# the loss function is  0.736485427162154
# the loss function is  0.6492708769787511
# the loss function is  0.7433214324860867
# the loss function is  0.7327265029093698
# the loss function is  0.6643188159957361
# the loss function is  0.7371240957451254
# the loss function is  0.7268361544806541
# the loss function is  0.6635199545356549
# the loss function is  0.7600266689908398
# the loss function is  0.669885100517
# the loss function is  0.7480375480104279
# the loss function is  0.7864136031918807
# the loss function is  0.7755807317130713
# the loss function is  0.668552451269219
# the loss function is  0.7173397384674337
# the loss function is  0.726539122261697
# the loss function is  0.6427051861022589
# the loss function is  0.6573574005549132
# the loss function is  0.6571293253324875
# the loss function is  0.6469759751025254
# the loss function is  0.6592657951721815
# the loss function is  0.667263072913598
# the loss function is  0.6548957168580701
# the loss function is  0.6397892067961504
# the loss function is  0.6589650396401305
# the loss function is  0.7318840326562164
# the loss function is  0.7304873516295405
# the loss function is  0.6506332192829987
# the loss function is  0.6631399649942739
# the loss function is  0.6624464825768023
# the loss function is  0.6646863018135878
# the loss function is  0.6615235141103444
# the loss function is  0.7317957380734683
# the loss function is  0.6552663138902265
# the loss function is  0.6603843408675031
# the loss function is  0.6490518688513564
# the loss function is  0.7503737493260403
# the loss function is  0.6571907984873517
# the loss function is  0.7223780054037305
# the loss function is  0.659688387507686
# the loss function is  0.6599061630720617
# the loss function is  0.6575333401066155
# the loss function is  0.6548849737622475
# the loss function is  0.7364706321961324
# the loss function is  0.6504198149552685
# the loss function is  0.6598374649388276
# the loss function is  0.6481562270097334
# the loss function is  0.7306931102730213
# the loss function is  0.6593158328308292
# the loss function is  0.6616533669257679
# the loss function is  0.6733951618106491
# the loss function is  0.7385436472844851
# the loss function is  0.6591077689791237
# the loss function is  0.6569150523213244
# the loss function is  0.6306258488159259
# the loss function is  0.6511963766927638
# the loss function is  0.6694079467691448
# the loss function is  0.7293206197249041
# the loss function is  0.6482772092626715
# the loss function is  0.6497796366152792
# the loss function is  0.6558441587005074
# the loss function is  0.8562359867584771
# the loss function is  0.6498772410632063
# the loss function is  0.6634798869961711
# the loss function is  0.6563945907031937
# the loss function is  0.6604689259225439
# the loss function is  0.8023199107732931
# the loss function is  0.654500138482346
# the loss function is  0.7483871978454202
# the loss function is  0.6525981628392541
# the loss function is  0.7243428726712525
# the loss function is  0.7546758450396078
# the loss function is  0.6406588329484141
# the loss function is  0.6440831470929962
# the loss function is  0.6203652744553688
# the loss function is  0.7353668745507863
# the loss function is  0.6610388290510207
# the loss function is  0.6691801139631544
# the loss function is  0.6367686030727598
# the loss function is  0.6213657817474451
# the loss function is  0.6390815278011642
# the loss function is  0.7214855007523743
# the loss function is  0.6556172608632235
# the loss function is  0.6654684333319197
# the loss function is  0.7530801377351763
# the loss function is  0.65742799677909
# the loss function is  0.7316279949022356
# the loss function is  0.6747698835214988
# the loss function is  0.7795352204576707
# the loss function is  0.7414865436515458
# the loss function is  0.6604171528473072
# the loss function is  0.6781079519498496
# the loss function is  0.6353254702115044
# the loss function is  0.7586266305236453
# the loss function is  0.6639423296297148
# the loss function is  0.6398268872118072
# the loss function is  0.6505499235930005
# the loss function is  0.6551902032451613
# the loss function is  0.7350986582315354
# the loss function is  0.6559485836794176
# the loss function is  0.6651258597909023
# the loss function is  0.6352656009898446
# the loss function is  0.7384247974331782
# the loss function is  0.6574554440610021
# the loss function is  0.6605800340747066
# the loss function is  0.6494173199971583
# the loss function is  0.7193606633212002
# the loss function is  0.6780587183087495
# the loss function is  0.7642986730266951
# the loss function is  0.5696777040581746
# the loss function is  0.7855673066194417
# the loss function is  0.7272356679189862
# the loss function is  0.6466955518850032
# the loss function is  0.671449919227399
# the loss function is  0.6623171956929057
# the loss function is  0.746769544794719
# the loss function is  0.7289445931537638
# the loss function is  0.6601403792600129
# the loss function is  0.5938312118103747
# the loss function is  0.6608489026269933
# the loss function is  0.6584488405450633
# the loss function is  0.726272127582506
# the loss function is  0.6474013257358073
# the loss function is  0.661289793372305
# the loss function is  0.6423044670238371
# the loss function is  0.7380005123567611
# the loss function is  0.6630392096139621
# the loss function is  0.6564168611744404
# the loss function is  0.6661037480264629
# the loss function is  0.657655011840742
# the loss function is  0.6498059092896746
# the loss function is  0.6571546785888835
# the loss function is  0.6585404009690574
# the loss function is  0.6662125093408771
# the loss function is  0.6366326728884147
# the loss function is  0.7563271079562329
# the loss function is  0.645040615298362
# the loss function is  0.6562967265974347
# the loss function is  0.6423839822904382
# the loss function is  0.7263410254874573
# the loss function is  0.742062636795006
# the loss function is  0.6578797051052773
# the loss function is  0.7339133475784255
# the loss function is  0.661292016667459
# the loss function is  0.6507238708371779
# the loss function is  0.6493318517778838
# the loss function is  0.6292271543531994
# the loss function is  0.7494119006875493
# the loss function is  0.7295884558086919
# the loss function is  0.6619339355461792
# the loss function is  0.6521751407180962
# the loss function is  0.6794039089804754
# the loss function is  0.6611111743583854
# the loss function is  0.7646656564468909
# the loss function is  0.7272797789930852
# the loss function is  0.7254383483896065
# the loss function is  0.7530837880583584
# the loss function is  0.6288413991290218
# the loss function is  0.6530873317368993
# the loss function is  0.7421425643947175
# the loss function is  0.6488147282901628
# the loss function is  0.6497677829669922
# the loss function is  0.6182754958405163
# the loss function is  0.6584907260588553
# the loss function is  0.7592726007293722
# the loss function is  0.637479762427982
# the loss function is  0.5983834625638512
# the loss function is  0.6521081665865253
# the loss function is  0.7684730840339081
# the loss function is  0.7596023087846852
# the loss function is  0.7399506891959983
# the loss function is  0.6470468984183175
# the loss function is  0.7579253671998968
# the loss function is  0.6473985592108182
# the loss function is  0.6649706707279532
# the loss function is  0.755321248588061
# the loss function is  0.7425969971604246
# the loss function is  0.6129837158268112
# the loss function is  0.7554772334041113
# the loss function is  0.7314942342679215
# the loss function is  0.7361006274592279
# the loss function is  0.6595122634568054
# the loss function is  0.6537185474926056
# the loss function is  0.6719692653963673
# the loss function is  0.7294371788441297
# the loss function is  0.6403032548702595
# the loss function is  0.6635116122628515
# the loss function is  0.6496203603018457
# the loss function is  0.63170404709244
# the loss function is  0.6108357016971323
# the loss function is  0.6734873990853595
# the loss function is  0.6579789743394159
# the loss function is  0.6450138367630037
# the loss function is  0.6409863520987347
# the loss function is  0.632064786078945
# the loss function is  0.631204687057903
# the loss function is  0.6577872673896212
# the loss function is  0.665877471480503
# the loss function is  0.6582599334596123
# the loss function is  0.7569749021509374
# the loss function is  0.6494789052233136
# the loss function is  0.678196260367623
# the loss function is  0.634492412960472
# the loss function is  0.6549353362829785
# the loss function is  0.7495177245174782
# the loss function is  0.6574087260614903
# the loss function is  0.7408776092752785
# the loss function is  0.6537858262332479
# the loss function is  0.7398155652197914
# the loss function is  0.641951173891004
# the loss function is  0.6576862977572111
# the loss function is  0.6417604430307022
# the loss function is  0.6642295415685291
# the loss function is  0.7339070720554792
# the loss function is  0.6056420605778998
# the loss function is  0.6406810928120641
# the loss function is  0.6598635696127101
# the loss function is  0.7531633321598675
# the loss function is  0.664675165965813
# the loss function is  0.7432243102215448
# the loss function is  0.8071448671179419
# the loss function is  0.6511550896114253
# the loss function is  0.7270214552813321
# the loss function is  0.650849578974121
# the loss function is  0.8130278821090525
# the loss function is  0.6548215598438305
# the loss function is  0.7284035609413294
# the loss function is  0.754284123553584
# the loss function is  0.6413227244713379
# the loss function is  0.6502628042063054
# the loss function is  0.7371713581608769
# the loss function is  0.6586998951529716
# the loss function is  0.6478394019402766
# the loss function is  0.6563038256578173
# the loss function is  0.631058723580631
# the loss function is  0.6486862059468288
# the loss function is  0.7616658662261702
# the loss function is  0.7470246453085458
# the loss function is  0.6667067624078007
# the loss function is  0.7282526222146661
# the loss function is  0.6680579534616684
# the loss function is  0.6471312870552719
# the loss function is  0.679513464237386
# the loss function is  0.6477227967045692
# the loss function is  0.6567812833860338
# the loss function is  0.7611923191529674
# the loss function is  0.7638645139521782
# the loss function is  0.6505877330730819
# the loss function is  0.6484850813116421
# the loss function is  0.7408440568754724
# the loss function is  0.6574685183964858
# the loss function is  0.6673950864676621
# the loss function is  0.6341709444342362
# the loss function is  0.6605021033789866
# the loss function is  0.6541616400558973
# the loss function is  0.7351724015922941
# the loss function is  0.7447012626941368
# the loss function is  0.6548762504457091
# the loss function is  0.6615219834168663
# the loss function is  0.6557654096427514
# the loss function is  0.723019875653608
# the loss function is  0.64749794467382
# the loss function is  0.7774356283711852
# the loss function is  0.6696924161921249
# the loss function is  0.6481933659070048
# the loss function is  0.6568507961672371
# the loss function is  0.65653136372692
# the loss function is  0.8224369598386585
# the loss function is  0.6624833644509034
# the loss function is  0.6687668674933805
# the loss function is  0.646050032916268
# the loss function is  0.6609361240725112
# the loss function is  0.6564705347198941
# the loss function is  0.6493112690684703
# the loss function is  0.6553452404487554
# the loss function is  0.6590289056940629
# the loss function is  0.7378337075606571
# the loss function is  0.7527871445542688
# the loss function is  0.6563733490436908
# the loss function is  0.6342092622783466
# the loss function is  0.6523750074931367
# the loss function is  0.6741577854600992
# the loss function is  0.6540638697502476
# the loss function is  0.664404588668982
# the loss function is  0.7862552080082829
# the loss function is  0.7303132559404086
# the loss function is  0.6609681877816876
# the loss function is  0.7797260667660062
# the loss function is  0.731060693698234
# the loss function is  0.6461015469531691
# the loss function is  0.6423318772120675
# the loss function is  0.6405252499835646
# the loss function is  0.6600176645478183
# the loss function is  0.6501982097130475
# the loss function is  0.7768105282497707
# the loss function is  0.6620669762723035
# the loss function is  0.6408418483490085
# the loss function is  0.7288131783924225
# the loss function is  0.7279730888691062
# the loss function is  0.6359625933600024
# the loss function is  0.7589556036190274
# the loss function is  0.7506147948543793
# the loss function is  0.6526671718639648
# the loss function is  0.6443488152063349
# the loss function is  0.732892601365205
# the loss function is  0.7263793716621353
# the loss function is  0.7513095754680074

# %%
prediction = logistic.predict(X_test)
# Out:
# shape of theta (9, 9)
# shape of x copy (7, 8)
# shape of intercept (7, 1)
# shape (7, 9)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: overflow encountered in exp

# %% [markdown]
# Compute the accuracy

# %%
y_hat = (prediction > 0.5).astype(int)

# %%
np.sum(y_hat == y_true.reshape(-1,1)) / len(y_true)
# Out:
# 4.571428571428571

# %%
#dataset=data.drop(['SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'],axis=1)

# %%
#dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  Outcome
# 0            6      148             72        1
# 1            1       85             66        0
# 2            8      183             64        1
# 3            1       89             66        0
# 4            0      137             40        1

# %% [markdown]
# Features selection : Wrapper method

# %% [markdown]
# Forward selection

# %%
def validation(data, eval_features, select,target):
        '''
            This method takes the list of features, return the best feature with his RMSE 
        '''
        data = data[:]
        logistic=LogisticRegresion(lr=0.00000001,max_iteration=100)
        accuracy=[]
        best_feature=[]
        split_index=int(len(data)*80/100)
        #print(eval_features)
        for f in eval_features:
            inter = select[:]
            inter.append(f[0])
            #print(inter)
            X=data[inter].values
            #print(inter)
            y=data[target].values.reshape(-1,1)
            #print('shape of y',y.shape)
            X_train =X[0:split_index]
            X_test=X[split_index:]
            #print(X_train.shape)
            y_train=y[0:split_index].reshape(-1,1)
            y_true=y[split_index:]
            y=y.reshape(-1,1)
            #print(y_train.shape)
            #print(X_test.shape)
            logistic.fit_BGD(X_train,y_train)
            acc=logistic.error_prediction(X_test,y_true)
            accuracy.append(acc)
        best_feature = eval_features[np.argmax(accuracy)]
        #print(accuracy)    
        return best_feature

# %%
def forward(data, target):
    remaining = data.columns.tolist()
    remaining.remove(target)
    #remaining=[remaining]
    #print(remaining)
    selected = []
    l=len(remaining)
    k=5
    while l>k:
        eval_feature = []
        for candidate in remaining:
            #selected.append()
            eval_feature.append([candidate])
        #print(selected)
        best = validation(data,eval_feature,selected,target)
        #print(best)
        #print(remaining)
        
        remaining=list(set(remaining)-set(best))
        #print(l)
        l-=1
        #print(remaining)
        selected.append(best[0])
    print('The best features', selected)

# %%
forward(data, 'Outcome')
# Out:
# The best features ['Pregnancies', 'SkinThickness', 'BloodPressure']

# %% [markdown]
# Backward elimination

# %%
def backward(data,target):
        '''
            Backward elimination 
        '''
        data = data[:]
        remaining = data.columns.tolist()
        remaining.remove(target)
        logistic=LogisticRegresion(lr=0.00000001,max_iteration=100)
        
        accuracy=[]
        best_feature=[]
        split_index=int(len(data)*80/100)
        #print(eval_features)
        #print(data.shape)
        k=4
        while len(remaining)>k:
            for f in remaining:

                X=data[f].values.reshape(-1,1)
                #print(inter)
                y=data[target].values.reshape(-1,1)
                #print('shape of y',y.shape)
                X_train =X[0:split_index]
                X_test=X[split_index:]
                #print(X_train.shape)
                y_train=y[0:split_index].reshape(-1,1)
                y_true=y[split_index:]
                y=y.reshape(-1,1)
                #print(y_train.shape)
                #print(X_test.shape)
                logistic.fit_BGD(X_train,y_train)
                acc=logistic.error_prediction(X_test,y_true)
                accuracy.append(acc)
            excluded_feature = remaining[np.argmin(accuracy)]
            remaining.remove(excluded_feature)   
        return remaining

# %%
backward(data,'Outcome')
# Out:
# ['Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
