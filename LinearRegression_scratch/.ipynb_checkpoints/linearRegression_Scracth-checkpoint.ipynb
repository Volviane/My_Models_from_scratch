# %% [markdown]
# #Linear regression from scratch:
#
# 1- Numerical Approach:
# (Batch Gradient Descent, Stochatics Gradient Descent)
# 2- Analitycal Aproach

# %%
import numpy as np
import pandas as pd

# %%
#data generating

# %%
X_train=np.arange(0,20).reshape(-1,1)
X_test=np.arange(21,25).reshape(-1,1)
print(X_train.shape)
print(X_test.shape)
# Out:
# (20, 1)
# (4, 1)

# %%
y_train=(2*X_train).reshape(-1,1)
true_y=2*X_test.reshape(-1,1)
print(y_train.shape)
print(true_y.shape)
# Out:
# (20, 1)
# (4, 1)

# %%
class LinearRegression:
    def __init__(self,lr=0.01, max_iter=10):
        self.lr=lr
        self.max_iter=max_iter
        
    def loss(self,y,theta,x):
        return (1/(2*len(x)))* np.sum((y - x@theta)**2)
    
    def get_gradient(self,y, theta, x):
        return (1/(len(x)))*np.sum((x@theta-y)*x, axis=0)
    
    
    #Batch gradient descent
    def fit_BGD(self,X,y):
        
        #make a copy of our data
        X_copy=X.copy()
        
        #add the intercept column
        intercept=np.ones((X_copy.shape[0],1))
        X_copy=np.concatenate((intercept, X_copy), axis=1)
        print(X_copy.shape)
        #initialise the weight
        self.theta=np.zeros((X_copy.shape[1],1))
        #print(theta)
        print('shape of theta',self.theta.shape)
        #print('shape of x',X_copy.shape)
        #print('shape of y',y.shape)
        
        for i in range(self.max_iter):
            grad = self.get_gradient(y, self.theta, X_copy)
            #print('gradient',grad.shape)
            self.theta = self.theta - self.lr*grad.reshape(-1,1)
            #print('shape of theta',self.theta.shape)
            print('the loss is',self.loss(y,self.theta,X_copy))
    
    #stochastic gradient descent
    def fit_SGD(self,X,y):
        #make a coy of X
        X_copy=X.copy()
        #add the intercept
        
        intercept=np.ones((X_copy.shape[0],1))
        X_copy=np.concatenate((intercept,X_copy),axis=1)
        
        #initialize the weight
        self.theta=np.zeros((X_copy.shape[1],1))
        
        
        for i in range(self.max_iter):
            #shuffle the data
            shuffle_vector=np.random.permutation(X_copy.shape[0])
            #for one trainig set
            for j in shuffle_vector:
                #compute the gradient
                gradient= self.get_gradient(y[j],self.theta,X_copy[j])
                #update the weight
                self.theta = self.theta - self.lr*gradient.reshape(-1,1)
                
                print ('The loss is', self.loss(y[j],self.theta,X_copy[j]))
    
    #metod to solve analytically
    def fit_analytically(self,X,y):
        X_copy=X.copy()
        intercept=np.ones((X_copy.shape[0],1))
        X_copy=np.concatenate((intercept,X_copy),axis=1)
        
        #self.theta = np.zeros((X_copy.shape[1],1))
        
        self.theta=np.linalg.solve(X_copy.T@X_copy,X_copy.T@y)
        
        print('The mimimum value of theta is \n',self.theta,'\nThe loss is ', self.loss(y, self.theta, X_copy))
        
        
        
    def predict(self,X):
        X_copy=X.copy()
        intercept=np.ones((X_copy.shape[0],1))
        print('shape of theta',self.theta.shape)
        #print('shape of intercept', intercept.shape)
        #print('shape of x copy', X_copy.shape)
        X_copy=np.concatenate((intercept,X_copy),axis=1)
        print('shape of x_copy', X_copy.shape)
        return X_copy@self.theta

# %%
linearReg=LinearRegression(lr=0.01,max_iter=10)

# %%
linearReg.fit_analytically(X_train,y_train)
# Out:
# The mimimum value of theta is
#  [[0.]
#  [2.]]
# The loss is  0.0

# %%
linearReg.fit_BGD(X_train,y_train)
# Out:
# (20, 2)
# shape of theta (2, 1)
# the loss is 14.506975000000006
# the loss is 0.8548038012499992
# the loss is 0.05312288510998401
# the loss is 0.0060319596356099466
# the loss is 0.003251177456302545
# the loss is 0.003072401559057719
# the loss is 0.0030465001025298363
# the loss is 0.003029657884840527
# the loss is 0.0030134295351188774
# the loss is 0.002997318697365723

# %%
linearReg.fit_SGD(X_train,y_train)
# Out:
# The loss is 20.5209
# The loss is 0.0436601025
# The loss is 127.55691504504507
# The loss is 1.5543043471490052
# The loss is 0.3464153103007736
# The loss is 0.001154388958903874
# The loss is 0.5231539692391675
# The loss is 0.5653991504671781
# The loss is 0.20710095244499546
# The loss is 0.01964442701020948
# The loss is 0.4435703397702228
# The loss is 0.4545239625880076
# The loss is 7.87995279303025e-06
# The loss is 8.657419883703912e-05
# The loss is 0.7234338135174225
# The loss is 0.0029997485935289035
# The loss is 0.07764210045886417
# The loss is 0.009849825992424836
# The loss is 0.4857170867205943
# The loss is 0.0019307675631619486
# The loss is 0.0006493114692187576
# The loss is 0.005350248351575458
# The loss is 0.6055200108133058
# The loss is 0.07521475807130117
# The loss is 2.014004781032431
# The loss is 0.0006691632059710627
# The loss is 0.006622555006400214
# The loss is 0.009689897583281194
# The loss is 0.0002518307280401042
# The loss is 0.039396453012209294
# The loss is 0.2029626063258132
# The loss is 0.33004989063514556
# The loss is 0.09317522393903009
# The loss is 0.3077564232568156
# The loss is 0.7818910752926814
# The loss is 0.45133417474608295
# The loss is 0.013985761307852498
# The loss is 0.0005693321938575444
# The loss is 0.6087277276637013
# The loss is 0.005878426021704837
# The loss is 0.2292945950467977
# The loss is 0.03528320185485305
# The loss is 0.0003468721241492652
# The loss is 0.5457071477112914
# The loss is 0.6549616772045922
# The loss is 0.0071221427717161265
# The loss is 0.016019030267703883
# The loss is 0.03167968082913222
# The loss is 0.00016590690199211545
# The loss is 0.035122674523855625
# The loss is 0.07522989081320478
# The loss is 0.00012259743738116534
# The loss is 0.4588478489529251
# The loss is 0.027274269280013336
# The loss is 0.003599072286560011
# The loss is 0.011480233080101277
# The loss is 0.38859163129586527
# The loss is 0.5290370200951415
# The loss is 0.45723589929128866
# The loss is 0.8659460992078971
# The loss is 0.0009660363073268379
# The loss is 0.07328659167642647
# The loss is 0.008994937931332549
# The loss is 0.34445363592517164
# The loss is 0.0044893417333718095
# The loss is 0.6058093941493801
# The loss is 0.017600668622063793
# The loss is 0.24181610737011783
# The loss is 0.038345882887235214
# The loss is 0.6715346772083818
# The loss is 0.01783174615609056
# The loss is 0.8402002046100556
# The loss is 0.6668089913411136
# The loss is 0.3572164929776796
# The loss is 0.0072755721986734675
# The loss is 0.0351416046958815
# The loss is 0.18873171885783674
# The loss is 0.14544465037738794
# The loss is 0.2384930862167942
# The loss is 7.485671981240275e-05
# The loss is 2.994268792515782e-08
# The loss is 0.00012202567558886358
# The loss is 0.69038857002429
# The loss is 0.5080252082207604
# The loss is 0.8371167770274109
# The loss is 0.14176798949449188
# The loss is 0.0038340054194728286
# The loss is 0.1093025579080063
# The loss is 0.4176954310197656
# The loss is 0.1481796820031104
# The loss is 0.032128392924618145
# The loss is 0.011586634201635242
# The loss is 0.04405534722333632
# The loss is 0.012754508909940945
# The loss is 0.10488563912363588
# The loss is 0.0011202535948570175
# The loss is 0.8665503385117826
# The loss is 0.3279051107383026
# The loss is 0.005275116118476164
# The loss is 0.07016403787899352
# The loss is 0.42788332599170986
# The loss is 0.021225189332311777
# The loss is 2.0761625707347253
# The loss is 1.3045528806847404
# The loss is 0.05067054837836531
# The loss is 0.43971965743762337
# The loss is 0.0003699769202239142
# The loss is 0.015075569141048035
# The loss is 0.00019179601226801334
# The loss is 0.6468756957118998
# The loss is 0.8057435668917532
# The loss is 7.504729066299784e-05
# The loss is 0.010007651083923435
# The loss is 0.15367359583439305
# The loss is 0.0520491947047921
# The loss is 0.1334970787355437
# The loss is 5.204263613785657e-05
# The loss is 0.45756635966271625
# The loss is 0.17809827588044325
# The loss is 0.0019071150194376301
# The loss is 0.15373855450716076
# The loss is 0.103340892068784
# The loss is 0.030472205841570545
# The loss is 0.037269150768414326
# The loss is 0.201563377999198
# The loss is 0.000817014327117812
# The loss is 0.6100480475073086
# The loss is 6.30821857957267e-05
# The loss is 0.2769310806172074
# The loss is 0.006493978733210749
# The loss is 0.7035913626139241
# The loss is 6.592085744444523e-06
# The loss is 0.14177541818261413
# The loss is 0.013934866718016388
# The loss is 0.0024268247510044064
# The loss is 0.00022738900111869516
# The loss is 0.348689420833166
# The loss is 0.7976931655215803
# The loss is 0.0011776220503182532
# The loss is 0.178494869744414
# The loss is 0.13666013464806714
# The loss is 0.08109427121088465
# The loss is 0.3600803407125253
# The loss is 0.0277963772398818
# The loss is 0.00016654999890316564
# The loss is 0.841758131617103
# The loss is 0.09059657406712522
# The loss is 0.04987412900577249
# The loss is 0.00010636345244495697
# The loss is 0.5806899742339945
# The loss is 0.02404999172326318
# The loss is 0.16779328881817523
# The loss is 0.697823520862848
# The loss is 1.1573438383745767e-05
# The loss is 0.022580511385910336
# The loss is 0.40841315277605006
# The loss is 0.09763218198778066
# The loss is 0.47608222059870436
# The loss is 2.8930671445229367e-06
# The loss is 0.14202188398817545
# The loss is 0.0017567045937648866
# The loss is 0.8675933268543135
# The loss is 0.021040256762575413
# The loss is 0.035579464962933176
# The loss is 0.5530506382659786
# The loss is 0.018894601128738676
# The loss is 0.321847455568423
# The loss is 0.00010584046002663372
# The loss is 0.19648687352341285
# The loss is 0.856439754599668
# The loss is 0.22771757276052618
# The loss is 0.003650939202125311
# The loss is 0.18902793623972644
# The loss is 0.0012125663061287545
# The loss is 0.27745778998017523
# The loss is 0.06490619962920573
# The loss is 0.00104389217717552
# The loss is 0.5989476859896354
# The loss is 0.051389277946729726
# The loss is 0.018223738306182072
# The loss is 0.011888493952250261
# The loss is 0.13148157911764566
# The loss is 0.3454036390406798
# The loss is 0.3203685190310757
# The loss is 0.3992394332433871
# The loss is 0.1348214293294822
# The loss is 0.3102985734076774
# The loss is 0.2145734524190541
# The loss is 3.8350654222368e-05
# The loss is 0.3834591580727185
# The loss is 2.4150373518847164e-06
# The loss is 2.264994684204084e-06
# The loss is 0.0016387596776194302
# The loss is 0.7438355191003101
# The loss is 1.5560591977957153e-05
# The loss is 0.011337134105279232
# The loss is 0.835719022053721
# The loss is 0.005024464071006681
# The loss is 0.4744566118665581
# The loss is 0.013387733131759632
# The loss is 0.40744219195855574
# The loss is 0.5530854723902154
# The loss is 0.0865056047851107
# The loss is 0.0017875556412688285
# The loss is 2.9606233652350037e-07
# The loss is 0.03122611269382979
# The loss is 0.038520628901781526
# The loss is 0.21207132781104848
# The loss is 0.07828860587619972
# The loss is 0.29309349872669616
# The loss is 1.6720933466453918
# The loss is 0.30898366240581454
# The loss is 0.3538097417744889
# The loss is 0.04340845310187056
# The loss is 0.0004870080686675598
# The loss is 0.03692828977240035
# The loss is 0.0026218580562112842
# The loss is 0.2115096528189956
# The loss is 0.008532797590319172
# The loss is 0.7781249496673746
# The loss is 0.38100540317068077
# The loss is 0.03697945001924544
# The loss is 0.5128729269065017
# The loss is 0.00847651729510543
# The loss is 0.10993076176669767
# The loss is 0.019495754205915993
# The loss is 0.8531491905184392
# The loss is 0.12358535699524367
# The loss is 0.3353557004217734
# The loss is 0.647091597906319
# The loss is 0.011172351719033228
# The loss is 0.22492804383649295
# The loss is 0.060585409982767575
# The loss is 0.0392257590339232
# The loss is 0.4625126118348081
# The loss is 0.013687116661934663
# The loss is 4.557626882015202e-05
# The loss is 2.835411843987172e-06
# The loss is 0.020236701647476214
# The loss is 0.01840850889004044
# The loss is 0.06123194349925601
# The loss is 0.135637945943314
# The loss is 0.7200173854076862
# The loss is 0.8925813397556575
# The loss is 0.001585298538516057
# The loss is 0.003138030554540651
# The loss is 0.006868533527693011
# The loss is 0.013892218757591227
# The loss is 2.208786446514363e-05
# The loss is 0.31475614313951567
# The loss is 0.5713465863068854
# The loss is 0.11693922823647274
# The loss is 0.12572072132377887
# The loss is 0.6754701965901989
# The loss is 0.014163698262354174
# The loss is 0.0019404456882038442
# The loss is 0.0404904287251759
# The loss is 0.35211013590223894
# The loss is 0.10231559316231752
# The loss is 0.007663465684556855
# The loss is 0.046920629863390684
# The loss is 0.0026581600454962137
# The loss is 0.7099688729996099
# The loss is 0.1873049390787235
# The loss is 0.07298672017428594
# The loss is 0.0046912306024814035
# The loss is 0.0015398681392380772
# The loss is 0.2753345806712513
# The loss is 4.3764749129740164e-05
# The loss is 0.01973869518605085
# The loss is 0.8271524142161312
# The loss is 0.34443218851261054
# The loss is 0.013962139459092564
# The loss is 0.40856588392405224
# The loss is 0.0024052176690795013
# The loss is 0.46350680801960725
# The loss is 0.28492109322350195
# The loss is 0.10782487549414098
# The loss is 0.0004792687902927798
# The loss is 0.01854739652045402
# The loss is 0.30733503808067336
# The loss is 0.2356194242480169
# The loss is 0.38318409536877057
# The loss is 0.025128411790576066
# The loss is 0.01787813222009698
# The loss is 0.0027372833178205577
# The loss is 0.09608951192533614
# The loss is 0.8259525337561822
# The loss is 0.0015616802922678163
# The loss is 0.4421871746326083
# The loss is 0.006595786739766515
# The loss is 0.8164583302291849
# The loss is 0.20535957297954577
# The loss is 0.04408451019795844
# The loss is 0.013017042518358538
# The loss is 0.04157284617626433
# The loss is 5.800546744481299e-05
# The loss is 0.08666428438201729
# The loss is 0.015050616952049845
# The loss is 0.456597659368405
# The loss is 0.16167783073389375
# The loss is 0.21126440509185587
# The loss is 0.44038093218775065
# The loss is 1.850630005946258e-05
# The loss is 0.07997594168359665
# The loss is 0.7171613866605409
# The loss is 0.029995911434865505
# The loss is 1.2560228886199978e-05
# The loss is 0.28409877231731306
# The loss is 0.9443315027894211
# The loss is 0.005193149672085074
# The loss is 0.001588642104502725
# The loss is 0.07449202438410762
# The loss is 0.8114954146241038
# The loss is 0.1085527236268735
# The loss is 0.41709525869146274
# The loss is 0.03933384088547105
# The loss is 0.028539554007930075
# The loss is 0.05774056641530617
# The loss is 0.12495848537410102
# The loss is 0.3691949367502118
# The loss is 0.007443843357817158
# The loss is 0.019018459187947076
# The loss is 0.6577694277069474
# The loss is 0.020532918821193114
# The loss is 0.5226674283380616
# The loss is 0.3271664695911228
# The loss is 5.8160416925942825e-05
# The loss is 0.10054762621040038
# The loss is 8.792801223193036e-05
# The loss is 0.007665540791198336
# The loss is 0.00014746913088451442
# The loss is 0.020733053448167067
# The loss is 0.327482158043461
# The loss is 0.14306008926327643
# The loss is 0.014243976301385143
# The loss is 0.021813774657251466
# The loss is 0.7903113089875767
# The loss is 0.405729996448748
# The loss is 2.016979700201849
# The loss is 2.016979700201849
# The loss is 0.06870989284805806
# The loss is 0.0038531762376335446
# The loss is 0.08910586948084978
# The loss is 9.335800465277613e-05
# The loss is 0.007681047991909067
# The loss is 0.09340913426774969
# The loss is 0.6053458104579448
# The loss is 0.759058204042233
# The loss is 0.25325963855453765
# The loss is 0.0527219006301589
# The loss is 0.20583855097386436
# The loss is 0.14558839140634325
# The loss is 0.316674128011902
# The loss is 0.6022302218201042
# The loss is 0.038111770108187816
# The loss is 0.001820046943004432
# The loss is 0.03272022834837288
# The loss is 0.834479125720344
# The loss is 0.00011333190378821202
# The loss is 0.04921324969383735
# The loss is 0.31589646353830403
# The loss is 0.785100746608334
# The loss is 0.06729397443559325
# The loss is 0.36164427410716576
# The loss is 0.033251904248525394
# The loss is 0.7039300398642604
# The loss is 0.06326702585826001
# The loss is 0.03539562072180921
# The loss is 0.6738355995720439
# The loss is 0.01469919253687607
# The loss is 4.991504492772558e-05
# The loss is 0.3971863776184788
# The loss is 3.577928571543818e-05
# The loss is 1.987049779379066e-06
# The loss is 0.04492738814210733
# The loss is 0.0854076543979792
# The loss is 1.0448000845000909
# The loss is 0.016148563018860414
# The loss is 0.015233113142718966
# The loss is 0.2327942106292813
# The loss is 0.016990661400592535
# The loss is 0.8253171031785602
# The loss is 0.16118516021221305
# The loss is 0.6362226282541275
# The loss is 0.4272766129823454
# The loss is 0.0009191243795987639
# The loss is 0.00018166222835227524
# The loss is 0.750406112198114
# The loss is 0.04742719876661278
# The loss is 0.031190484434036086
# The loss is 0.12957303591982475
# The loss is 0.027747207480301572
# The loss is 0.47567646121780555
# The loss is 8.031717230605983e-05
# The loss is 0.006701295544372257
# The loss is 0.0009923061158991322
# The loss is 0.0006199246616483303
# The loss is 0.0007825285029523356
# The loss is 0.17763630465455355
# The loss is 0.006187596998057495
# The loss is 0.5787618163245181
# The loss is 0.4739697489762652
# The loss is 0.07698825685487315
# The loss is 0.5594957138423619
# The loss is 0.009279135874365982
# The loss is 0.0003144490333728964
# The loss is 1.0480393495983539e-05
# The loss is 0.0016627606675229808
# The loss is 0.8380751100302342
# The loss is 0.0007668977368124539
# The loss is 0.23842415162852182
# The loss is 1.0958994764340186
# The loss is 0.9694204477791538
# The loss is 0.012222307107046443
# The loss is 3.382011366367744e-05
# The loss is 0.054507843985892215
# The loss is 0.20100637321874237
# The loss is 0.23109889657354207
# The loss is 0.3618177036836434
# The loss is 0.019059865108948484
# The loss is 0.7881815562748968
# The loss is 0.007290204006699351
# The loss is 0.00026477785133023233
# The loss is 0.0006650468096008034
# The loss is 0.6399008088922026
# The loss is 1.7623809341010624e-06
# The loss is 0.007234331051011971
# The loss is 0.26122460947342613
# The loss is 0.00012324039540641263
# The loss is 0.5005851956516073
# The loss is 0.9021740388126943
# The loss is 0.685061306783112
# The loss is 0.1327234969118082
# The loss is 0.17027110619756466
# The loss is 0.022031815177526705
# The loss is 0.14111955345930036
# The loss is 0.0006111311314247145
# The loss is 0.1867817035035876
# The loss is 0.0014423137752260877
# The loss is 0.11924546032611778
# The loss is 0.16018606171840885
# The loss is 0.7214531263716495
# The loss is 0.004595032916036379
# The loss is 0.09431892870595134
# The loss is 5.9528095076758515e-05
# The loss is 0.4291753975813798
# The loss is 0.15665067449030828
# The loss is 0.029289779335265925
# The loss is 0.4203697774092537
# The loss is 0.16529332159897533
# The loss is 0.7568828142616958
# The loss is 0.9060756438455324
# The loss is 0.006556567603517209
# The loss is 0.000722155412192018
# The loss is 0.1155465601729372
# The loss is 0.026657194537559593
# The loss is 3.2936280157382866e-05
# The loss is 0.028419105571827252
# The loss is 0.051850633227759374
# The loss is 0.00029988154504883945
# The loss is 0.004729766896262426
# The loss is 0.0045776005959227714
# The loss is 2.4127933080817623e-05
# The loss is 0.21794444511842606
# The loss is 7.93358789668544e-05
# The loss is 0.015288115939906456
# The loss is 0.0004973864572513297
# The loss is 0.4478222194131739
# The loss is 0.0001355575070374398
# The loss is 0.1181491064504505
# The loss is 0.3955828630984039
# The loss is 0.8868434396819159
# The loss is 0.05043155896382827
# The loss is 0.08302332824071941
# The loss is 0.23590478051570163
# The loss is 0.4360043720059672
# The loss is 0.7785148992926441
# The loss is 1.8314255812680607
# The loss is 0.6677216482142738
# The loss is 0.10157259400082273
# The loss is 0.005512535602222763
# The loss is 0.4328857463366776
# The loss is 0.25087322029433723
# The loss is 0.5210402056227499
# The loss is 0.2668758751431422
# The loss is 0.009906376274800927
# The loss is 0.6937613250021003
# The loss is 0.008883377629545476
# The loss is 0.2932031776688232
# The loss is 0.0003344053505274586
# The loss is 2.804573412217336e-06
# The loss is 0.020579407324544878
# The loss is 0.5084966492070679
# The loss is 0.8352133421517256
# The loss is 0.3639957794103914
# The loss is 0.022134133499280225
# The loss is 0.8427292692160254
# The loss is 0.054725870780554964
# The loss is 0.20129563462782774
# The loss is 0.6517035224832659
# The loss is 0.0344694863892971
# The loss is 0.013235145779656982
# The loss is 0.00251068120103482
# The loss is 0.0181323520858361
# The loss is 0.00011567953440606079
# The loss is 0.4686667588916756
# The loss is 0.2606609104280227
# The loss is 0.0005304347918534549
# The loss is 0.15567129472466104
# The loss is 0.6568690204714004
# The loss is 0.4152459011170667
# The loss is 0.9533131546288348
# The loss is 0.49530295654939144
# The loss is 3.814655241570085e-05
# The loss is 0.3185813270387819
# The loss is 0.04247718462570454
# The loss is 0.027087904403279284
# The loss is 0.6486825758954337
# The loss is 0.010791265763046617
# The loss is 0.16742248638633722
# The loss is 0.04169917686034891
# The loss is 0.1283435063860652
# The loss is 0.02058437730931367
# The loss is 0.15887279445963498
# The loss is 0.0016420453957491654
# The loss is 0.07322190667418817
# The loss is 0.0019847889820539684
# The loss is 2.517181572940079e-07
# The loss is 0.0016096474311002433
# The loss is 0.2756710970126254
# The loss is 0.8096839502498179
# The loss is 0.530553025906144
# The loss is 0.6427274646841822
# The loss is 0.30817292494667475
# The loss is 0.40495938245846935
# The loss is 0.06918450529616389
# The loss is 0.9009230160236752
# The loss is 0.23654758329435394
# The loss is 5.1058327572174624e-05
# The loss is 0.017626529073036988
# The loss is 0.0025690391179831957
# The loss is 0.07976162540949688
# The loss is 0.3926149316271682
# The loss is 0.813810108056064
# The loss is 0.05648882384945181
# The loss is 0.04321774621815352
# The loss is 0.6612333900635052
# The loss is 0.11641845536874508
# The loss is 0.00011957149621885019
# The loss is 0.3083407908988414
# The loss is 0.08903393107139516
# The loss is 0.029091741638416376
# The loss is 6.0477344351813113e-05
# The loss is 6.220550538784738e-05
# The loss is 0.02866102802098872
# The loss is 0.2617006532474859
# The loss is 0.002325850225325461
# The loss is 0.6541405825499594
# The loss is 0.1222357970628419
# The loss is 0.042277652382109225
# The loss is 0.6605714865241284
# The loss is 6.369797285372769e-06
# The loss is 0.14322648531797957
# The loss is 8.458009603914996e-05
# The loss is 0.001926061630780582
# The loss is 0.0007055474270462757
# The loss is 0.014753977759814912
# The loss is 0.10129055756811468
# The loss is 0.05078505573380243
# The loss is 0.19881360013740418
# The loss is 0.4423675689993136
# The loss is 0.831188525249943
# The loss is 0.5868965681341217
# The loss is 0.6787001036056689
# The loss is 0.02611956567923819
# The loss is 0.7107566769234526
# The loss is 0.01159060179777691
# The loss is 0.31341472812798327
# The loss is 0.4984646868195961
# The loss is 0.54714493622902
# The loss is 0.10626409897277346
# The loss is 9.533684541915089e-06
# The loss is 0.021718544351529957
# The loss is 0.46728179094922284
# The loss is 0.6532098413704842
# The loss is 0.9701392459807308
# The loss is 0.10865979897736912
# The loss is 4.8705989911167355e-05
# The loss is 0.0007943145343341277
# The loss is 0.20448923988701553
# The loss is 0.6416868527989242
# The loss is 0.05257120287304792
# The loss is 0.1504847761368927
# The loss is 9.838145973938585e-05
# The loss is 0.028640892110554546
# The loss is 0.005918088500057058
# The loss is 0.4088601825926164
# The loss is 0.019438426165282265
# The loss is 0.0013219347536075163
# The loss is 0.03153934364091001
# The loss is 0.5786839452797875
# The loss is 0.27633602319957784
# The loss is 0.00020675472439093823
# The loss is 0.00011029616847530733
# The loss is 0.842095684401069
# The loss is 0.2649701456137785
# The loss is 0.0007118261139332268
# The loss is 3.762196285899562e-05
# The loss is 0.0017608745561697686
# The loss is 0.7441485287930236
# The loss is 0.024523904552810505
# The loss is 0.020552057803919707
# The loss is 0.4655372446621147
# The loss is 0.03815131081293979
# The loss is 1.6875969292891182
# The loss is 0.3115038226593235
# The loss is 0.0329059280667954
# The loss is 0.2724287989847868
# The loss is 0.005655464931632578
# The loss is 0.04458541684285221
# The loss is 0.1282863124449232
# The loss is 0.9206807554998504
# The loss is 0.7039679388588286
# The loss is 0.40991894431038894
# The loss is 0.006785886294184676
# The loss is 0.22175978715452366
# The loss is 0.369457905307367
# The loss is 0.008419647186933341
# The loss is 6.205766256392323e-06
# The loss is 0.018353049287439836
# The loss is 0.16269242971245412
# The loss is 0.20526442406536197
# The loss is 0.6421350827590541
# The loss is 6.104821647997911e-05
# The loss is 0.19336540755609563
# The loss is 0.12955200508118722
# The loss is 4.5560694668265264e-05
# The loss is 7.40202114509417e-05
# The loss is 0.45233149423809016
# The loss is 0.0015455820480246292
# The loss is 0.04198280179141311
# The loss is 0.002049061011117905
# The loss is 0.0006635569557906519
# The loss is 0.8655983602761158
# The loss is 0.0010187757903570448
# The loss is 0.1894255904653968
# The loss is 0.0786263703736103
# The loss is 0.03745898498164301
# The loss is 0.0009131675890210326
# The loss is 0.39115508046605013
# The loss is 0.4151379605164032
# The loss is 2.399196756880019e-05
# The loss is 0.21794899284209102
# The loss is 0.6493743846822072
# The loss is 0.002133763561332974
# The loss is 0.016418967027374286
# The loss is 0.4589477040687394
# The loss is 0.0014116562744895037
# The loss is 1.1559346831459425
# The loss is 0.00044318739477267397
# The loss is 0.5695196963735242
# The loss is 0.05528441845599737
# The loss is 0.0004819777938137008
# The loss is 0.6214215923158282
# The loss is 0.00539724637484244
# The loss is 1.0726705008847082e-05
# The loss is 0.8697592217434232
# The loss is 0.002869279320347307
# The loss is 0.0027365346019487115
# The loss is 0.15691498212353974
# The loss is 0.18894187603340357
# The loss is 1.5908832565478217
# The loss is 0.295759291310548
# The loss is 0.3431670004634455
# The loss is 0.28687296761255665
# The loss is 0.010611798903426953
# The loss is 0.0626696226976301
# The loss is 0.29863588610377
# The loss is 0.06153081037073715
# The loss is 1.1518381302802328e-05
# The loss is 0.8531983463190156
# The loss is 0.19761743917896624
# The loss is 0.018155433457711926
# The loss is 0.0005570822462095465
# The loss is 0.13308155938878644
# The loss is 0.11641802909846131
# The loss is 0.0004951503446524463
# The loss is 0.413734666379252
# The loss is 0.03794004787790754
# The loss is 0.6126531074909563
# The loss is 0.15976289280990824
# The loss is 0.015227373390875083
# The loss is 0.3929609229458839
# The loss is 0.09589559252693625
# The loss is 0.0008855787568517188
# The loss is 0.6264497720480597
# The loss is 0.15028607879453165
# The loss is 0.01601885765820863
# The loss is 0.21442328915901837
# The loss is 0.2680385379010599
# The loss is 9.736605614331626e-06
# The loss is 7.243145192515065e-05
# The loss is 0.003353149932960477
# The loss is 0.5330097253315421
# The loss is 0.015150600428410464
# The loss is 0.40350357631800193
# The loss is 0.006084871054448702
# The loss is 0.45745403609977164
# The loss is 0.17563506282839117
# The loss is 0.20069343105733403
# The loss is 0.3966474266238275
# The loss is 0.13297210288832056
# The loss is 0.6635802826450667
# The loss is 0.26122777171655104
# The loss is 0.00020049850777816852
# The loss is 0.021072285524742707
# The loss is 0.10609764402078038
# The loss is 0.6941525515518547
# The loss is 0.8317370581390168
# The loss is 0.6520765031108802
# The loss is 0.0005372663053200719
# The loss is 0.3815333994440873
# The loss is 0.007616303791114699
# The loss is 0.5585038559075057
# The loss is 0.02073200058703733
# The loss is 0.1239362041004988
# The loss is 1.3452462890664456
# The loss is 0.09415961345023806
# The loss is 0.0004505276651803748
# The loss is 0.17445358078503623
# The loss is 0.007065171792799844
# The loss is 3.1882644514282694e-05
# The loss is 0.0001052417452056316
# The loss is 0.4093787044076422
# The loss is 0.8197618148306656
# The loss is 0.07322226663838244
# The loss is 0.4723617286239878
# The loss is 0.006080593907517566
# The loss is 0.1610774169028299
# The loss is 0.0030522391375872905
# The loss is 0.041928586661774944
# The loss is 0.393572305380001
# The loss is 0.0674793394231632
# The loss is 0.004524004387176196
# The loss is 0.5616582337741681
# The loss is 0.09739914558786134
# The loss is 0.022979475813922148
# The loss is 0.007709685839610296
# The loss is 0.05238514733036843
# The loss is 0.20547424135831854
# The loss is 8.98030221755473e-05
# The loss is 0.006619298893289847
# The loss is 0.01734687373759753
# The loss is 0.26365924038567873
# The loss is 0.7119541016170309
# The loss is 3.5031795947510667e-06
# The loss is 0.18597246969254594
# The loss is 0.9345174963968323
# The loss is 0.4305799366586405
# The loss is 0.007649969585546132
# The loss is 0.12468242260868319
# The loss is 4.274020461945666e-05
# The loss is 0.13675439405200523
# The loss is 0.42782198048191383
# The loss is 0.18257876236755013
# The loss is 0.8353414865887124
# The loss is 0.08118250945422785
# The loss is 0.0016283969276178472
# The loss is 0.3752746346828893
# The loss is 0.40306134134627053
# The loss is 0.0008371573969963421
# The loss is 0.02929522381294839
# The loss is 0.16627106385803936
# The loss is 0.0001163686906263073
# The loss is 0.08739133771920242
# The loss is 0.8233616385994185
# The loss is 0.7261504277396551
# The loss is 0.01235177878841487
# The loss is 0.10757806218583074
# The loss is 0.16451099830329974
# The loss is 0.10286000519257603
# The loss is 0.10732074835066545
# The loss is 0.40476347537272384
# The loss is 9.13940417594708e-06
# The loss is 7.265322253327178e-05
# The loss is 0.04242584406810567
# The loss is 0.026956575343622814
# The loss is 0.007126228378662217
# The loss is 0.5422916710021786
# The loss is 0.048268021045489926
# The loss is 0.564133132714362
# The loss is 0.0008767854345068124
# The loss is 0.695047571486358
# The loss is 0.09956510267852128
# The loss is 0.0008912901273537481
# The loss is 0.8133243695710765
# The loss is 8.509886285792853e-05
# The loss is 0.19495394720447007
# The loss is 0.0485690358046676
# The loss is 0.003568350820222125
# The loss is 0.04889502330579105
# The loss is 0.4011613143750765
# The loss is 3.207967669475651e-05
# The loss is 0.08365268829382075
# The loss is 0.23648421089903074
# The loss is 0.0020091433639543104
# The loss is 0.005867443304843003
# The loss is 0.1433336533103201
# The loss is 0.0028824811733073885
# The loss is 0.08096941943227308
# The loss is 0.0025476337167661665
# The loss is 0.16050609510408573
# The loss is 0.3559518895002697
# The loss is 0.7517805068581723
# The loss is 0.00031690387125041486
# The loss is 0.6070359740352409
# The loss is 0.005639945220318855
# The loss is 0.8305379561735099
# The loss is 0.05095125867094834
# The loss is 5.252214603612969e-05
# The loss is 0.3189592286432775
# The loss is 0.8251690969584745
# The loss is 0.010903272738250718
# The loss is 0.027489789443517234
# The loss is 0.15711088385537106
# The loss is 8.768919207650688e-06
# The loss is 0.018279003578068703
# The loss is 0.6548948559689542
# The loss is 0.17553770339505262
# The loss is 0.43570485642454854
# The loss is 0.10313877190735576
# The loss is 0.03664653372389321
# The loss is 0.17824013977396544
# The loss is 0.44615298308082874
# The loss is 0.00850666733787141
# The loss is 0.00124892425484252
# The loss is 0.3895894008954407
# The loss is 0.6333673153739403
# The loss is 0.2695600539607953
# The loss is 0.05901351243189525
# The loss is 0.005978767352685921
# The loss is 0.6651962537766137
# The loss is 0.3372078259855583
# The loss is 0.035955933175901025
# The loss is 0.4269470520715391
# The loss is 0.023535197211574762
# The loss is 0.0011380689286889661
# The loss is 0.032496526226324096
# The loss is 0.13247051202245413
# The loss is 0.028454094724180926
# The loss is 0.9006895753632488
# The loss is 0.1622590108375434
# The loss is 0.20496493074717353
# The loss is 0.6793576879116401
# The loss is 0.8645674137673687
# The loss is 0.398625929962252
# The loss is 0.0023899125663239236
# The loss is 2.3572631196196734e-07
# The loss is 0.0015906916602410378
# The loss is 0.07447897693800291
# The loss is 0.1434062973179003
# The loss is 0.14492362529176242
# The loss is 0.2616805717462128
# The loss is 0.2699857690881722
# The loss is 0.00993370165071458
# The loss is 0.07793840997602984
# The loss is 0.11156027447611334
# The loss is 0.8157970750105554
# The loss is 0.4399436697411905
# The loss is 0.861171410315792
# The loss is 0.08781961813970338
# The loss is 9.274323562285645e-05
# The loss is 0.00015518950704316266
# The loss is 0.0003039448183744121
# The loss is 0.0001811637405077688
# The loss is 0.005303704737316681
# The loss is 0.003514822984047992
# The loss is 0.5040811820007468
# The loss is 0.3183785258517941
# The loss is 0.006281770333707806
# The loss is 0.016458740772386876
# The loss is 0.680092841497503
# The loss is 0.2415544077740169
# The loss is 0.047304646717265725
# The loss is 0.16053076889354173
# The loss is 0.02609607212018153
# The loss is 1.900945783990524e-07
# The loss is 0.00012396999085921142
# The loss is 0.19869513157224675
# The loss is 0.3695055827348102
# The loss is 0.035171178457493874
# The loss is 0.41843542123504657
# The loss is 0.003431886583774955
# The loss is 0.18543543299820497
# The loss is 0.7471424550494997
# The loss is 0.18841233621334316
# The loss is 0.8549070209490155
# The loss is 0.2578238376212175
# The loss is 0.2145576625468512
# The loss is 1.0887825367813911e-05
# The loss is 0.008756120114054815
# The loss is 0.010170237455860195
# The loss is 0.2037145784196316
# The loss is 0.0008559014360804063
# The loss is 0.010843554069941749
# The loss is 0.014725504691296309
# The loss is 0.21601160775939235
# The loss is 0.00033727496963229
# The loss is 0.8646858928126716
# The loss is 0.3229039216674261
# The loss is 0.3626801519149402
# The loss is 0.44902965340739476
# The loss is 3.748742443745438e-05
# The loss is 1.4607531861526508
# The loss is 1.0008889781357098
# The loss is 0.15678862807807026
# The loss is 0.0012167959478542303
# The loss is 0.0028217894348771507
# The loss is 0.13084394599541385
# The loss is 5.4740782298853116e-06
# The loss is 0.2187893140953465
# The loss is 0.3523049770335607
# The loss is 0.030702334435829242
# The loss is 0.0019995670993370037
# The loss is 0.0440164456945156
# The loss is 0.0005364930082153428
# The loss is 0.10610233533738118
# The loss is 0.23436558963848186
# The loss is 0.07674275878449613
# The loss is 0.1661730562509904
# The loss is 0.02012060572165894
# The loss is 0.46488033081879193
# The loss is 0.5961743459617479
# The loss is 1.635245776309699
# The loss is 0.3029882961585572
# The loss is 0.22656528710846294
# The loss is 0.7933852548403907
# The loss is 0.00759946045617433
# The loss is 0.0007592660473683371
# The loss is 0.5307745159011444
# The loss is 0.05737210011125921
# The loss is 5.586852541637333e-05
# The loss is 0.7073591033257661
# The loss is 0.1840188869525353
# The loss is 0.19545942956383128
# The loss is 0.00447376958648093
# The loss is 0.8542008695557071
# The loss is 0.0006457897698529182
# The loss is 0.007030158350849862
# The loss is 0.021080847694650552
# The loss is 0.13404771965399012
# The loss is 0.08812464021962545
# The loss is 0.0004885826074921866
# The loss is 0.11524358183801851
# The loss is 0.3280457796797397
# The loss is 0.00477443157908007
# The loss is 0.4644847044817121
# The loss is 0.6426721534006199
# The loss is 0.09100379715807747
# The loss is 0.022750949289519637
# The loss is 0.10736701105725717
# The loss is 0.8222692478794258
# The loss is 0.00507100833137379
# The loss is 0.11493033346235236
# The loss is 0.007815556638051993
# The loss is 0.04817728462328497
# The loss is 0.8257550310509216
# The loss is 2.7299634745875664e-06
# The loss is 0.22716240954012737
# The loss is 0.4291569617338686
# The loss is 0.008201484175355189
# The loss is 0.005819538279981899
# The loss is 2.4128311052161434e-06
# The loss is 0.08363491173570305
# The loss is 0.4044189672588034
# The loss is 0.1886367467895475
# The loss is 0.027667288497929304
# The loss is 0.17075668405775868
# The loss is 0.4226098475861073
# The loss is 0.2840777231360491
# The loss is 0.006227329391119309
# The loss is 0.42942670318479625
# The loss is 9.105891687699458e-05
# The loss is 0.1649071253631019
# The loss is 0.053760054908731904
# The loss is 0.006896829743100051
# The loss is 0.178162952501138
# The loss is 0.1705355185802959
# The loss is 0.03022951415415067
# The loss is 0.8332032990429827
# The loss is 0.654622451936572
# The loss is 0.8265097344474177
# The loss is 0.3240936098512808
# The loss is 0.0004273954043848962
# The loss is 0.28249660396772325
# The loss is 0.01953630425202475
# The loss is 2.4463072057947235e-05
# The loss is 0.5645558394945088
# The loss is 0.0012180018673799062
# The loss is 0.047840919171249274
# The loss is 0.03814813398545487
# The loss is 0.018018848880471873
# The loss is 1.7989808479046768e-05
# The loss is 0.7046027660451818
# The loss is 0.07623861655492373
# The loss is 0.9119966521513887
# The loss is 0.1252774321995706
# The loss is 0.43012020585414357
# The loss is 0.261119976703381
# The loss is 0.03745155152650178
# The loss is 0.23945838586074747
# The loss is 0.0002720856834659362
# The loss is 0.004942065010207052
# The loss is 0.13242462162238183
# The loss is 0.27787012027696717
# The loss is 0.4679212686598125
# The loss is 1.2240072343876223
# The loss is 0.01821694993720536
# The loss is 0.1261046551726986
# The loss is 0.7098680058134513
# The loss is 0.508925733888566
# The loss is 0.48423358656278914
# The loss is 0.01708513335901266
# The loss is 0.5308426556236062
# The loss is 0.03528472534769288
# The loss is 0.10273499828908421
# The loss is 0.7784886978040394
# The loss is 0.06111085934634499
# The loss is 0.007289076389592508
# The loss is 0.00016509530624249355
# The loss is 0.0020165075800789847
# The loss is 0.5252426231700551
# The loss is 0.0023793366815683154
# The loss is 2.2334629896063192e-05
# The loss is 0.03280814719909858
# The loss is 0.64267214879881
# The loss is 1.7396268594928512e-05
# The loss is 0.0038091065071538055
# The loss is 6.177222644247304e-06
# The loss is 0.08549444281179876
# The loss is 2.271664846597744e-05
# The loss is 0.8530181757232367
# The loss is 0.2923624486993465
# The loss is 0.07264411601711755
# The loss is 0.09399187129704273
# The loss is 0.0005700878823920998
# The loss is 0.009861448816354921
# The loss is 0.997473698512255
# The loss is 0.02398553991258199
# The loss is 0.7268940215631077
# The loss is 0.10393423361830302
# The loss is 0.7273075682653581
# The loss is 0.0036259807261424452
# The loss is 0.00328955191520648
# The loss is 0.011498506614834016
# The loss is 0.3498261630658234
# The loss is 0.004422600729737469
# The loss is 0.000665322013403778
# The loss is 0.0003817214502005551
# The loss is 0.6383100495738325
# The loss is 0.00039827269367303955
# The loss is 0.2578190136284709
# The loss is 0.038928663545172236
# The loss is 0.16118544740547977
# The loss is 0.8279626423159603
# The loss is 0.015261668388831194
# The loss is 0.7614890862984836
# The loss is 0.06450379992394598
# The loss is 0.3781746560421434
# The loss is 0.4452896389655171
# The loss is 0.008494901322035642
# The loss is 0.011197157399685553
# The loss is 0.4158692826894407
# The loss is 0.08621778647248292
# The loss is 0.00012886932810509256
# The loss is 0.0025618350977357237
# The loss is 0.12454008302769683
# The loss is 0.3405908171022966
# The loss is 0.00018286318315080947
# The loss is 5.065875906477661e-05
# The loss is 2.149722709269118e-06
# The loss is 0.7059448907920123
# The loss is 0.1822478422793169
# The loss is 0.0014035826625369275
# The loss is 0.2765217148456996
# The loss is 0.06442812558941442
# The loss is 0.278494913904092
# The loss is 1.8533259187012248
# The loss is 0.33836078379741186
# The loss is 0.8143704097165129
# The loss is 0.0008389427622818377
# The loss is 0.019340237301872166
# The loss is 0.0003802794160725346
# The loss is 0.08508802984450813
# The loss is 0.06343905545553072
# The loss is 0.0010510202850245762
# The loss is 0.45939680396417387
# The loss is 0.7018138553450585
# The loss is 0.06315479889439012
# The loss is 0.7356721798570973
# The loss is 6.3789149182611905e-09
# The loss is 0.08494870186787673
# The loss is 0.13572876470816647
# The loss is 0.16573295056526147
# The loss is 0.011829294886574825
# The loss is 0.836097226495736
# The loss is 0.5074133834994179
# The loss is 0.7518080206519451
# The loss is 0.33566314989404405
# The loss is 9.190794054712793e-05
# The loss is 0.0014142799397813318
# The loss is 0.5519054168207681
# The loss is 0.25006741879764993
# The loss is 0.10762752057036355
# The loss is 0.007221476349654205
# The loss is 4.5075226924604234e-05
# The loss is 0.00470460184246238
# The loss is 0.1460459100496119
# The loss is 0.1138457806589781
# The loss is 0.10211300758915536
# The loss is 0.000646749897451156
# The loss is 0.4916381719762886
# The loss is 0.0029910569092190813
# The loss is 0.012939322052622207
# The loss is 0.0004470142632071332
# The loss is 0.7166819258107151
# The loss is 0.13568222452604817
# The loss is 0.11140674869386356
# The loss is 0.8625036780881742
# The loss is 0.22020208082538792
# The loss is 0.000540153803355853
# The loss is 0.1149298772553547
# The loss is 0.18818416053249565
# The loss is 0.13756020236366479
# The loss is 0.44589812763804676
# The loss is 0.022562562597915354
# The loss is 4.144734151712167e-05
# The loss is 0.31414695193663145
# The loss is 0.048391837650521255
# The loss is 0.0039118595019227995
# The loss is 0.7033516181766426
# The loss is 0.05815663027858558
# The loss is 0.021011128509741364
# The loss is 0.6430323770971825
# The loss is 0.34350612122457036
# The loss is 0.02301489951946093
# The loss is 0.0013466106547736787
# The loss is 0.11842370902111742
# The loss is 9.599175621744817e-05
# The loss is 0.07661613048650354
# The loss is 0.4003450717845552
# The loss is 0.1861877826918748
# The loss is 0.001774154668574044
# The loss is 0.00417320201552516
# The loss is 0.33151445502808224
# The loss is 0.7911631316956999
# The loss is 1.4653822142122928
# The loss is 0.02094884597235285
# The loss is 0.017510992967693123
# The loss is 0.16188175228811932
# The loss is 0.24417109129837153
# The loss is 0.38604553408855863
# The loss is 0.6400223818621817
# The loss is 0.015363097438982513
# The loss is 0.013565327604020745
# The loss is 0.8496058465900586
# The loss is 7.249920247455085e-06
# The loss is 0.033112277452310906
# The loss is 0.13898659508190864
# The loss is 0.0035035475509925633
# The loss is 0.4458989090932934
# The loss is 0.6375968059770304
# The loss is 0.08910021489036131
# The loss is 0.4380411145552753
# The loss is 0.0011228757357147035
# The loss is 0.728823985726631
# The loss is 0.0022738948444353474
# The loss is 2.7733487530591283e-05
# The loss is 1.3076541936161552e-05
# The loss is 0.0015087655939523335
# The loss is 8.924814277000468e-05
# The loss is 0.19985780737594813
# The loss is 0.680914251788588
# The loss is 0.0418107521446718
# The loss is 0.5125714622870613
# The loss is 0.0527925994197512
# The loss is 0.0631432751611812
# The loss is 0.4406503340857412
# The loss is 0.00023388838293235832
# The loss is 0.027209104494718424
# The loss is 0.3501722033068582
# The loss is 0.0003203103645454119
# The loss is 0.29646352344159943
# The loss is 7.103921509213035e-07
# The loss is 0.34242694207146646
# The loss is 0.7953280688982767
# The loss is 0.001676215456684397
# The loss is 0.004924748441836159
# The loss is 0.6043565460777607
# The loss is 0.013528857224908758
# The loss is 0.0015706193483522451
# The loss is 0.17537638933918984
# The loss is 0.13766422677874854
# The loss is 0.01295930556631167
# The loss is 0.6193907447634907
# The loss is 0.32315008361727865
# The loss is 0.9431237546646636
# The loss is 0.4597332199735859
# The loss is 0.6420213243467967
# The loss is 0.01148361077430757
# The loss is 0.3860198721631563
# The loss is 0.4134941413982202
# The loss is 0.008059227577940434
# The loss is 7.40827447137633e-05
# The loss is 1.8308177131916631e-06
# The loss is 0.31593073761312607
# The loss is 0.00020403683257131378
# The loss is 0.009734995588600684
# The loss is 0.04766936455905962
# The loss is 0.11688813617241647
# The loss is 0.008380512389465909
# The loss is 2.206317357578257e-05
# The loss is 0.10607332767370249
# The loss is 0.14693031190167624
# The loss is 0.00021124778479658275
# The loss is 0.0001182686320971011
# The loss is 0.7237829664240678
# The loss is 0.07510440870801154
# The loss is 0.0007755219010776791
# The loss is 0.1634608613859327
# The loss is 0.04318853300759897
# The loss is 0.029893485890327785
# The loss is 0.005497234105450762
# The loss is 0.4528577091968563
# The loss is 0.5194781297871862
# The loss is 0.0010733414457605082
# The loss is 0.5202301487788437
# The loss is 0.9626223039283863
# The loss is 0.09798379818721902
# The loss is 0.0059241877157394296
# The loss is 0.002669972740954555
# The loss is 0.42451761766940876
# The loss is 0.5509338368888816
# The loss is 0.00026868089332844543
# The loss is 0.3221951210237107
# The loss is 0.017403816788200247
# The loss is 0.4492320337836539
# The loss is 0.1707533218053579
# The loss is 0.0002243803064599217
# The loss is 0.5793324983186395
# The loss is 0.6788839009524
# The loss is 0.048810680626812375
# The loss is 0.0158808844633308
# The loss is 0.0021424028354670526
# The loss is 0.8755174915901633
# The loss is 0.10900469246040222
# The loss is 0.0009729647244269038
# The loss is 0.14952047480868685
# The loss is 0.04612452956270868
# The loss is 0.004866621850734299
# The loss is 0.05804906742807505
# The loss is 0.4454799176147682
# The loss is 0.10905100821498058
# The loss is 0.17278050146693333
# The loss is 0.012745925176406872
# The loss is 0.6755763658633824
# The loss is 0.08091862164592643
# The loss is 0.0001231785050764075
# The loss is 0.7999436523811402
# The loss is 0.09025626248871771
# The loss is 0.4640418201288669
# The loss is 0.2852775323118241
# The loss is 0.0006965802851833389
# The loss is 0.002118076100305614
# The loss is 0.5090707521091793
# The loss is 0.5621829504846111
# The loss is 0.0001705284548575458
# The loss is 3.311398581019249e-06
# The loss is 0.0015652520191676662
# The loss is 0.2754578381310064
# The loss is 0.0265777251911129
# The loss is 0.793705399933488
# The loss is 0.41271972830644965
# The loss is 0.06449934941424401
# The loss is 0.0037266747852861062
# The loss is 0.019283220848044416
# The loss is 0.11629991563148044
# The loss is 0.15916569124372426
# The loss is 0.11266353165734193
# The loss is 0.028355142581820002
# The loss is 0.008814923857488147
# The loss is 0.0008673577939789976
# The loss is 0.17060469670627154
# The loss is 0.6652883481452767
# The loss is 0.06365323728188656
# The loss is 5.90572910610402e-05
# The loss is 0.07789919630404789
# The loss is 0.40110175779878365
# The loss is 0.4831731604960161
# The loss is 0.40895776304382786
# The loss is 0.015317076651659654
# The loss is 0.4037378880123109
# The loss is 0.09628610180482301
# The loss is 0.024974114087183488
# The loss is 0.7097701249854304
# The loss is 0.011277675664694802
# The loss is 0.0018137526278939216
# The loss is 0.5961914411318547
# The loss is 0.07118416401174654
# The loss is 0.13622315960928683
# The loss is 1.2167250567340302
# The loss is 0.174212892101456
# The loss is 0.8879295021482276
# The loss is 1.4776578322287002e-05
# The loss is 0.04578330727963812
# The loss is 0.1257956153275898
# The loss is 0.0068491596988212436
# The loss is 0.1460053921109715
# The loss is 0.049624829590447034
# The loss is 0.9015672829997244
# The loss is 0.10537848928816465
# The loss is 0.00024661737473426985
# The loss is 0.58828819418285
# The loss is 0.19173813993374217
# The loss is 0.21633680524477797
# The loss is 0.0012166000883280887
# The loss is 1.1443855797275095
# The loss is 0.9738461588960912
# The loss is 0.1342505468408305
# The loss is 0.0005204696100752178
# The loss is 0.1479730215279861
# The loss is 0.1379595334016116
# The loss is 0.0173684946330176
# The loss is 0.4351887791851739
# The loss is 3.436008682878189e-05
# The loss is 0.035763352383659554
# The loss is 0.0034675519930702434
# The loss is 0.13868245358123882
# The loss is 2.6050435761409358e-05
# The loss is 0.430075271732858
# The loss is 1.6760122952474437e-05
# The loss is 0.08524799906854881
# The loss is 0.0030391928572337614
# The loss is 0.855643101653694
# The loss is 0.0007858421560674815
# The loss is 0.08061591838135526
# The loss is 0.8136542795598467
# The loss is 0.24612379100113788
# The loss is 9.902787837123169e-05
# The loss is 0.27368789403325006
# The loss is 0.07003020139943594
# The loss is 0.0028374563675644528
# The loss is 0.3796135996893949
# The loss is 0.013485691143292036
# The loss is 0.00012006847756563816
# The loss is 0.14260313125918353
# The loss is 0.4327238793229498
# The loss is 0.00024950542644758413
# The loss is 0.0043570438923618855
# The loss is 0.05906628907802128
# The loss is 0.6715082294280352
# The loss is 0.0396381932355047
# The loss is 5.882487569559586e-06
# The loss is 0.4309992452106275
# The loss is 0.01826457845398369
# The loss is 0.808894532402575
# The loss is 0.09994931822154762
# The loss is 0.029265296089881373
# The loss is 9.080788962524026e-06
# The loss is 0.1000080291729468
# The loss is 0.25226788874913975
# The loss is 0.8623991340850807
# The loss is 0.4153673713082428
# The loss is 0.03423732371814203
# The loss is 0.2912167807170565
# The loss is 0.011935804261454254
# The loss is 0.2711543921998265
# The loss is 0.0017701277442085262
# The loss is 0.00039925656401612337
# The loss is 3.87629263746839e-06
# The loss is 0.0838976711394006
# The loss is 0.22716266857501458
# The loss is 0.029889190832601456
# The loss is 0.00819886097862257
# The loss is 0.0016374836877722856
# The loss is 0.22677254479975736
# The loss is 0.20680144266554246
# The loss is 0.18906807460035602
# The loss is 0.2722358380675136
# The loss is 0.000423890901274995
# The loss is 0.8148368171179332
# The loss is 0.003302702964770244
# The loss is 0.7341793017203264
# The loss is 0.00931084730217673
# The loss is 0.3119382982610988
# The loss is 0.42148939376206845
# The loss is 0.4952716087957962
# The loss is 0.232352974248019
# The loss is 0.03360339089753388
# The loss is 0.053154733583999095
# The loss is 0.04070825307398597
# The loss is 0.009212313474962175
# The loss is 8.710819912514869e-06
# The loss is 0.0016571688117285337
# The loss is 0.8380646919273504
# The loss is 0.00023564254425429015
# The loss is 0.003095650498848668
# The loss is 0.5141188009217432
# The loss is 0.46270297802384297
# The loss is 0.5653363569566852
# The loss is 7.56508029991369e-05
# The loss is 0.09870841288623741
# The loss is 0.15857921181198958
# The loss is 0.5314954981097317
# The loss is 0.66033060925939
# The loss is 0.012565542958673508
# The loss is 0.7119448154075553
# The loss is 0.534650486715948
# The loss is 0.0027036499680600755
# The loss is 0.0027826290801426516
# The loss is 0.03394814001864101
# The loss is 0.175268746460404
# The loss is 0.458878755956688
# The loss is 0.03485566919802101
# The loss is 0.1883112675965361
# The loss is 0.6359528035960416
# The loss is 0.16366428455671997
# The loss is 0.8481331670028379
# The loss is 0.16337797710213686
# The loss is 0.008429789722853066
# The loss is 0.0010873444827586046
# The loss is 9.468303598526457e-06
# The loss is 0.007326991062294416
# The loss is 0.26144540653954895
# The loss is 0.0023420525826003216
# The loss is 0.01616809885671114
# The loss is 0.6239633418863706
# The loss is 0.30501613040026726
# The loss is 0.25254271544613066
# The loss is 0.25254271544613066
# The loss is 0.11724820052586293
# The loss is 0.038271669858480954
# The loss is 0.05341480944980587
# The loss is 0.7945088309577116
# The loss is 0.002073653923801827
# The loss is 0.005774362739973924
# The loss is 1.2392330455388928e-05
# The loss is 0.08413520588645862
# The loss is 0.8221072451517124
# The loss is 0.0011226851228230011
# The loss is 0.0020018302871608793
# The loss is 0.24413930186724395
# The loss is 0.048518214108073575
# The loss is 0.4043268899439961
# The loss is 0.010523292669215957
# The loss is 0.01211454586801809
# The loss is 0.34757386931888606
# The loss is 0.4465711079951869
# The loss is 0.008381231820172448
# The loss is 0.0006570885747015601
# The loss is 0.07954778776786753
# The loss is 0.2349490880761118
# The loss is 0.0006356807114017084
# The loss is 0.04700978374046653
# The loss is 0.8005240870254267
# The loss is 0.05607437803907425
# The loss is 0.8446742779019943
# The loss is 0.026106488154531357
# The loss is 3.701910329001675e-05
# The loss is 0.0014853131142676791
# The loss is 0.17678761847272706
# The loss is 0.5499016900283605
# The loss is 0.5325838459029633
# The loss is 0.23778653904935493
# The loss is 0.0012330278582062062
# The loss is 0.0017325509084682045
# The loss is 0.02251510740161136
# The loss is 0.5382082085123614
# The loss is 0.08164684745268284
# The loss is 0.015604322524698481
# The loss is 0.007662332397841952
# The loss is 0.6602503670137281
# The loss is 0.8614604204464484
# The loss is 0.5932344999921247
# The loss is 0.005492972559853187
# The loss is 0.027007369499761492
# The loss is 0.2238644955514122
# The loss is 0.19937079847022648
# ...
# The loss is 0.12843763856111065
# The loss is 0.12197371058236492
# The loss is 0.06060614023822237
# The loss is 0.09437386762506755
# The loss is 0.00038017858553515064
# The loss is 0.0050886470635677855
# The loss is 0.28562123601740347
# The loss is 0.4025315412449874
# The loss is 0.0007321820670756363
# The loss is 0.2505517603003521
# The loss is 0.051566638567242834
# The loss is 0.5830593170299194
# The loss is 0.2018224285879155
# The loss is 0.17767291520202483
# The loss is 2.008655233309386e-05
# The loss is 0.5823887277243405
# The loss is 0.005432426466688606
# The loss is 0.0014703177789186419
# The loss is 0.07705301768034029
# The loss is 0.34537807453788893
# The loss is 0.595328161580319
# The loss is 0.00027668125882173724
# The loss is 0.0019353046210559095
# The loss is 0.1832154678045514
# The loss is 0.8102689951519088
# The loss is 0.9940317578122373
# The loss is 0.15551249785062066
# The loss is 0.05049228176631302
# The loss is 0.03233863527942045
# The loss is 0.07473533070163502
# The loss is 0.6030232824049624
# The loss is 0.14914565173526179
# The loss is 0.36395767522911676
# The loss is 0.015115311993924362
# The loss is 7.137436136701777e-06
# The loss is 0.0014611058086872297
# The loss is 0.05421451912452301
# The loss is 2.19181150122985e-06
# The loss is 0.21907187595619806
# The loss is 0.8222593055393628
# The loss is 0.018934457561915613
# The loss is 0.025858308595596183
# The loss is 1.625034959420796e-06
# The loss is 0.05634318699785388
# The loss is 0.20206411285220452
# The loss is 0.7142468769007455
# The loss is 0.28753689717430275
# The loss is 0.33484896658748187
# The loss is 0.005256610868094372
# The loss is 0.019807267872624698
# The loss is 0.681338613704021
# The loss is 0.08031374513443341
# The loss is 0.00015545446348420606
# The loss is 0.4171692892169841
# The loss is 0.09675617400830144
# The loss is 0.12069763840977152
# The loss is 0.3328448648798061
# The loss is 0.5970564397200883
# The loss is 0.7777747743087322
# The loss is 0.4869585110830437
# The loss is 0.1731078019271465
# The loss is 0.007021923540667732
# The loss is 0.07004205890381902
# The loss is 0.06268062582041387
# The loss is 0.006797684729122661
# The loss is 0.0003489123563305629
# The loss is 0.004490660782805154
# The loss is 0.48489093323285015
# The loss is 0.00024802392839926615
# The loss is 0.07305909662741154
# The loss is 0.7139710665327867
# The loss is 0.421086514099993
# The loss is 4.4330001486925326e-05
# The loss is 0.16403514901239324
# The loss is 0.019553711170542113
# The loss is 0.12234341794014073
# The loss is 0.0017516847826207769
# The loss is 0.0030176791384316005
# The loss is 5.3879839785356554e-05
# The loss is 0.008207084192291996
# The loss is 0.1374938310175933
# The loss is 0.0005048278118713564
# The loss is 0.09203669513929376
# The loss is 0.1668549223926211
# The loss is 0.587827481853759
# The loss is 0.2859784118426819
# The loss is 0.3820972048420658
# The loss is 0.8847436700903492
# The loss is 0.0001365424823513426
# The loss is 0.007928654838786865
# The loss is 0.0004832750913131447
# The loss is 0.02199423479765435
# The loss is 0.8426510641924385
# The loss is 0.3820399547691824
# The loss is 0.06270338672184615
# The loss is 0.08593270955183564
# The loss is 0.993803181967524
# The loss is 0.015548533979431567
# The loss is 0.01565053035461408
# The loss is 0.12701103731433325
# The loss is 0.32038747210766694
# The loss is 0.05756187849365128
# The loss is 0.4007149021384114
# The loss is 0.07154060750777055
# The loss is 0.007163384054010132
# The loss is 0.7531948744609823
# The loss is 0.003366117187645116
# The loss is 0.0029078093769051515
# The loss is 0.5021001189703137
# The loss is 0.20252468218259298
# The loss is 0.0001166068305158412
# The loss is 0.08250256463123465
# The loss is 0.8214695144344375
# The loss is 0.0011360707237569872
# The loss is 0.39360790506196935
# The loss is 0.06745146450973552
# The loss is 0.5772199058750809
# The loss is 0.1914671122336442
# The loss is 0.5253426534309863
# The loss is 0.0008903742177563731
# The loss is 0.029167684659212635
# The loss is 0.001546477171547981
# The loss is 0.02261482931650815
# The loss is 0.0038467475141316177
# The loss is 0.18051453876266876
# The loss is 0.006828135464362428
# The loss is 1.1230353065158216e-05
# The loss is 0.21845689979679905
# The loss is 0.305479663675908
# The loss is 0.07123818756479161
# The loss is 0.044810860187438996
# The loss is 0.7995244985626639
# The loss is 0.41406384267242524
# The loss is 0.8538722973642169
# The loss is 0.0006157882539722756
# The loss is 0.0007492616157703852
# The loss is 1.1707212746432021e-05
# The loss is 0.0030507468108848775
# The loss is 0.18718235542144063
# The loss is 0.06515535772543359
# The loss is 0.4227427517381064
# The loss is 0.4641771248043024
# The loss is 0.8935877515379959
# The loss is 0.5705365973694954
# The loss is 0.0332658773866196
# The loss is 2.7338213725850706e-05
# The loss is 0.03431041308732446
# The loss is 0.8188851430120477
# The loss is 0.42146957386961975
# The loss is 0.00021994127398112582
# The loss is 0.007628873191608377
# The loss is 0.005433698120764318
# The loss is 0.5618451504713102
# The loss is 0.11519649858453955
# The loss is 0.008087869981370118
# The loss is 0.04648505594654679
# The loss is 0.155814760546995
# The loss is 0.34414698673470256
# The loss is 0.006656504390692057
# The loss is 0.6888877313583877
# The loss is 0.010163977832465677
# The loss is 0.022745313777019136
# The loss is 0.5385006510449459
# The loss is 0.03894223830316971
# The loss is 0.003984631134441991
# The loss is 6.30836955466048e-06
# The loss is 0.22038714544549326
# The loss is 0.0033499104417264378
# The loss is 0.008189143947520242
# The loss is 0.002364712789045537
# The loss is 0.27258448480629277
# The loss is 0.8098148840833268
# The loss is 1.0041181531864225
# The loss is 0.19871806586470844
# The loss is 0.10831389497937238
# The loss is 0.6128391276664752
# The loss is 0.30569146574817724
# The loss is 0.2404473064457893
# The loss is 0.17243125457072545
# The loss is 0.6955659278617267
# The loss is 0.0011818421107653064
# The loss is 0.12936069713472478
# The loss is 0.02575102630780309
# The loss is 1.6891782787996613e-07
# The loss is 0.08502372082643928
# The loss is 0.013621356505419163
# The loss is 0.0007491013031792521
# The loss is 0.07364631183792392
# The loss is 0.10701880451586238
# The loss is 0.3206577030724858
# The loss is 0.006132862871342514
# The loss is 0.03716060666830357
# The loss is 0.836640785035381
# The loss is 0.0002862318256434639
# The loss is 0.2838415824833487
# The loss is 0.4723482703665784
# The loss is 0.11805116166120011
# The loss is 0.817793391357689
# The loss is 0.001865632863334171
# The loss is 0.31739085969343744
# The loss is 0.006211077246420457
# The loss is 0.09760017283868914
# The loss is 0.8050827401315815
# The loss is 0.014669164185884279
# The loss is 0.15552019626569388
# The loss is 0.01042743567906415
# The loss is 0.0011822656660297195
# The loss is 0.043657645032099
# The loss is 0.5749779728088851
# The loss is 9.480926999115182e-06
# The loss is 0.5639818662008308
# The loss is 0.007221391070571594
# The loss is 0.0007533451556922618
# The loss is 0.010728870944875523
# The loss is 0.002695815376388745
# The loss is 0.10744725888746141
# The loss is 0.2047797922981877
# The loss is 0.016584437032639794
# The loss is 0.40548359654647426
# The loss is 0.010932376247538485
# The loss is 0.22716937491672493
# The loss is 0.0002307451698931059
# The loss is 2.614318955676118e-06
# The loss is 0.030924618187132154
# The loss is 0.12237162256233204
# The loss is 8.894661024649923e-05
# The loss is 0.0005748510383347291
# The loss is 0.008709248537900918
# The loss is 0.034882250327873586
# The loss is 0.5621972082795179
# The loss is 0.9641223512734555
# The loss is 0.10007344079910263
# The loss is 0.7364813342929893
# The loss is 0.43436038485386
# The loss is 0.49660047942292695
# The loss is 0.8330178423750256
# The loss is 0.009285679645166765
# The loss is 0.7119296360803641
# The loss is 0.03121064057147932
# The loss is 0.48011752143140424
# The loss is 0.004089123219113428
# The loss is 9.5312154068567e-05
# The loss is 0.3270465326810438
# The loss is 0.30178232722163245
# The loss is 0.1925986201213299
# The loss is 0.0010487122855800746
# The loss is 0.02355980795992637
# The loss is 0.0020034985692444717
# The loss is 7.796273047446833e-06
# The loss is 0.1433031674186797
# The loss is 0.13746475957786075
# The loss is 0.23993383562507872
# The loss is 0.4696662313179789
# The loss is 0.2817708572122365
# The loss is 0.002595102864446163
# The loss is 0.8687094281488171
# The loss is 0.5780732748891478
# The loss is 0.0602037344396446
# The loss is 0.2137293406840806
# The loss is 0.7885429925074556
# The loss is 0.026594108553431407
# The loss is 0.23041691921969285
# The loss is 0.02458159767050486
# The loss is 4.8883233657961394e-05
# The loss is 0.21726259789696578
# The loss is 0.05204822888787986
# The loss is 0.005866395970768675
# The loss is 0.010534533581975473
# The loss is 0.08434067708021946
# The loss is 0.14737795276639387
# The loss is 0.1362456985901881
# The loss is 0.1040259266441695
# The loss is 0.7116112515368778
# The loss is 0.0004688360050702116
# The loss is 0.0005557964415144199
# The loss is 0.015488313270810483
# The loss is 0.28531684886573316
# The loss is 0.2597249753282593
# The loss is 0.004493343372585776
# The loss is 0.5069501933116882
# The loss is 0.6270150856221285
# The loss is 0.288359149726955
# The loss is 0.4513093132878758
# The loss is 0.013985271387741203
# The loss is 4.7268574351081325e-06
# The loss is 0.242766214540826
# The loss is 0.04842635594091099
# The loss is 0.05748105313360364
# The loss is 0.14183569693508602
# The loss is 0.013390797073800162
# The loss is 0.0020884069695119903
# The loss is 5.13938510722627e-06
# The loss is 0.044788469290840675
# The loss is 0.8241764312275014
# The loss is 0.22260198289160746
# The loss is 0.000794837024138053
# The loss is 7.725355087830706e-05
# The loss is 0.42880560383364646
# The loss is 0.11766088411401411
# The loss is 0.02852206912387603
# The loss is 0.14074394921636096
# The loss is 0.11819131750491611
# The loss is 0.012072867045155606
# The loss is 0.5229651790602055
# The loss is 0.6386141355395287
# The loss is 0.017860385595806966
# The loss is 0.7248253607445725
# The loss is 0.06437149658581429
# The loss is 0.06862853792233514
# The loss is 0.007634336303234934
# The loss is 0.29091753404705156
# The loss is 0.29065284743689346
# The loss is 0.0022876266242268864
# The loss is 0.17599574412089306
# The loss is 0.8326356210123302
# The loss is 0.00045519403631060754
# The loss is 0.11545583591468567
# The loss is 0.18711392834029134
# The loss is 0.06657839726367774
# The loss is 2.168306366211281e-06
# The loss is 0.003432869413747291
# The loss is 0.011564929049776662
# The loss is 0.016917367388668482
# The loss is 0.01891390270610803
# The loss is 0.011318307455999873
# The loss is 0.0024243477947878786
# The loss is 0.32924941886234466
# The loss is 0.5647383314931637
# The loss is 0.8327981715521665
# The loss is 0.3579463338760323
# The loss is 0.01786745044663258
# The loss is 0.16098176894586777
# The loss is 0.002142548105408994
# The loss is 0.00015753191502314263
# The loss is 8.58394159093134e-05
# The loss is 0.6899422756187413
# The loss is 0.020023807931286323
# The loss is 0.3237281579275513
# The loss is 0.7881561178529306
# The loss is 0.4013149026863673
# The loss is 0.00020184475653308733
# The loss is 0.08174341668918488
# The loss is 0.0028828883386099553
# The loss is 0.4126485536431529
# The loss is 0.16805383733931795
# The loss is 8.039290246472905e-06
# The loss is 0.12062343996580413
# The loss is 0.001108340628035896
# The loss is 0.011185654241972568
# The loss is 0.29704886375904294
# The loss is 0.01655122475160219
# The loss is 0.4234832635597157
# The loss is 0.1575902080481099
# The loss is 0.8480635887974557
# The loss is 0.0025854377975287
# The loss is 0.00820919250074115
# The loss is 0.5157305648172411
# The loss is 0.00017481287308059309
# The loss is 0.8160403070747345
# The loss is 0.11866613082286429
# The loss is 0.7500096752538937
# The loss is 0.41170517104711907
# The loss is 0.07619068289763145
# The loss is 0.035326825069034944
# The loss is 0.016491218441971434
# The loss is 0.00012509674839672477
# The loss is 0.16532957549011612
# The loss is 0.03852892509835122
# The loss is 0.002965489614267141
# The loss is 0.5270470171757597
# The loss is 6.701104413504641e-07
# The loss is 0.705792548497954
# The loss is 0.027857897657156714
# The loss is 0.220922715465404
# The loss is 0.0034316470489709943
# The loss is 0.007191556271171995
# The loss is 0.007710357125073219
# The loss is 0.07100799285285642
# The loss is 0.695250581916433
# The loss is 0.011972809072675717
# The loss is 0.10643184071666265
# The loss is 0.05028986785869847
# The loss is 0.009896007996884258
# The loss is 0.2671216338173736
# The loss is 0.0015772209335460845
# The loss is 0.3914765783574733
# The loss is 0.06913271780364602
# The loss is 0.3680649466772474
# The loss is 0.1669161850354886
# The loss is 0.02031868815648123
# The loss is 0.629269453038351
# The loss is 0.00028349648123141626
# The loss is 0.03081539206273089
# The loss is 3.104723808613788e-05
# The loss is 0.564748363023769
# The loss is 0.832802211854599
# The loss is 0.0015141862176651494
# The loss is 0.030621094417898093
# The loss is 0.3676791576906806
# The loss is 0.864383525291788
# The loss is 0.08861887452771204
# The loss is 0.015597693144047502
# The loss is 0.08443555256817262
# The loss is 0.28564023143688144
# The loss is 1.899237655592135e-06
# The loss is 0.02054903085338285
# The loss is 0.0005191691922415884
# The loss is 0.6033468201419978
# The loss is 0.017558361670755418
# The loss is 0.721155745116367
# The loss is 0.5461087920927079
# The loss is 0.12316641238430055
# The loss is 0.5144403444518247
# The loss is 0.506790641983443
# The loss is 0.0018216359884049467
# The loss is 0.006235144604065125
# The loss is 0.0037832129342421365
# The loss is 0.00028610715637506173
# The loss is 0.11668035415889581
# The loss is 0.32931743532729557
# The loss is 0.42221217421172574
# The loss is 0.0001609684593238182
# The loss is 0.04311731586028157
# The loss is 0.23993190917768392
# The loss is 0.26905270101197654
# The loss is 0.025667404363373975
# The loss is 0.01888816446918169
# The loss is 0.15651331359734635
# The loss is 0.10050512397362164
# The loss is 0.8122642696429935
# The loss is 0.0024863474521872476
# The loss is 0.883638196948565
# The loss is 0.03983762666707919
# The loss is 0.0024961919563010948
# The loss is 0.0020078046536858313
# The loss is 0.06099905540234598
# The loss is 0.0663248302208893
# The loss is 0.004337271490732923
# The loss is 0.08295528483094959
# The loss is 0.0844448713068031
# The loss is 0.7072077061994936
# The loss is 0.8388285189125569
# The loss is 0.23201496986552597
# The loss is 0.5710066867833548
# The loss is 0.0011134695731860893
# The loss is 0.05111550209770992
# The loss is 0.15755165155243983
# The loss is 0.02900002416055448
# The loss is 0.15832436047180523
# The loss is 0.04836902315908049
# The loss is 0.01805982712106998
# The loss is 0.19597317265516515
# The loss is 0.6682321823503766
# The loss is 5.2154811506827376e-05
# The loss is 0.00014667283490832637
# The loss is 0.5435883321563693
# The loss is 0.824220679293609
# The loss is 0.0718625036462186
# The loss is 0.0031014599783773774
# The loss is 0.02564373601226531
# The loss is 0.02970426186594505
# The loss is 0.004758329517840629
# The loss is 0.03597099727594502
# The loss is 0.27089562487525976
# The loss is 0.00047115290559509833
# The loss is 0.33430700970530014
# The loss is 0.4262531461425015
# The loss is 0.9307042450388188
# The loss is 0.0003794795033503875
# The loss is 0.0011401647195113385
# The loss is 0.005943011225880845
# The loss is 0.05678948115251085
# The loss is 0.015594190598392078
# The loss is 0.7230242615590003
# The loss is 0.20408574209077215
# The loss is 0.6847093605494131
# The loss is 0.7010033485527283
# The loss is 0.33986942853396446
# The loss is 0.018537291930419447
# The loss is 0.15692829563051433
# The loss is 0.25715634499846757
# The loss is 0.036841407910698364
# The loss is 0.38767352873114513
# The loss is 0.18735927387330042
# The loss is 0.042699896111463666
# The loss is 0.854471170536031
# The loss is 0.26263374167821446
# The loss is 0.011211032346108029
# The loss is 0.5744884818575063
# The loss is 0.02654979520891324
# The loss is 0.6363367263641416
# The loss is 0.10391573365111528
# The loss is 0.00013509917525767642
# The loss is 0.0019113885127601633
# The loss is 0.0001673367492264818
# The loss is 0.002819861166101341

# %%
predict=linearReg.predict(X_test)
print(predict)
print(true_y)
# Out:
# shape of theta (2, 1)
# shape of x_copy (4, 2)
# [[42.]
#  [44.]
#  [46.]
#  [48.]]
# [[42]
#  [44]
#  [46]
#  [48]]

# %%
np.sqrt(np.mean(np.sum((predict - true_y)**2)))
# Out:
# 0.0

# %%
from random import randrange

# Split a dataset into k folds
def cross_validation_split(dataset, folds=3):
    dataset_split = list()
    dataset_copy = list(dataset)
    fold_size = int(len(dataset) / folds)
    for i in range(folds):
        fold = list()
        while len(fold) < fold_size:
            index = randrange(len(dataset_copy))
            fold.append(dataset_copy.pop(index))
        dataset_split.append(fold)
    return dataset_split

# %%
cross_validation_split(X_train)
# Out:
# [[array([1]), array([12]), array([7]), array([17]), array([0]), array([8])],
#  [array([6]), array([10]), array([16]), array([13]), array([11]), array([15])],
#  [array([5]), array([19]), array([9]), array([18]), array([2]), array([3])]]

# %%
def cross_validation(X):
    linearReg=LinearRegression(lr=0.01,max_iter=10)
    random_split = np.array(cross_validation_split(X))
    for i in range(3):
            
            for j in range(len(random_split)):
                print(random_split[j:])
                linearReg.fit_BGD(random_split[j+1:],y_train[j+1:])
                linearReg.predict(random_split[:j+1])

# %%
cross_validation(X_train)
# Out:
# [[[12]
#   [17]
#   [18]
#   [ 5]
#   [16]
#   [19]]
#
#  [[ 8]
#   [15]
#   [ 2]
#   [ 7]
#   [13]
#   [10]]
#
#  [[ 6]
#   [ 1]
#   [ 9]
#   [14]
#   [ 3]
#   [11]]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-5b81809687a1> in <module>()
# ----> 1 cross_validation(X_train)
#
# <ipython-input-103-e9e33f73b1ed> in cross_validation(X)
#       6             for j in range(len(random_split)):
#       7                 print(random_split[j:])
# ----> 8                 linearReg.fit_BGD(random_split[j+1:],y_train[j+1:])
#       9                 linearReg.predict(random_split[:j+1])
#
# <ipython-input-80-6fe431287b25> in fit_BGD(self, X, y)
#      19         #add the intercept column
#      20         intercept=np.ones((X_copy.shape[0],1))
# ---> 21         X_copy=np.concatenate((intercept, X_copy), axis=1)
#      22         print(X_copy.shape)
#      23         #initialise the weight
#
# ValueError: all the input arrays must have same number of dimensions
